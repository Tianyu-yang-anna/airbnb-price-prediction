# %% [markdown]
# ## Airbnb Data Cleaning
#
# Liqin Zhang - lz2809

# %%
import pandas as pd
import numpy as np
from numpy.random import seed
seed(123)
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import seaborn as sns
import geopandas as gpd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score
import xgboost as xgb
from xgboost import plot_importance
from sklearn.metrics import explained_variance_score, mean_squared_error, r2_score
import time
from keras import models, layers, optimizers, regularizers
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
from statsmodels.tsa.seasonal import seasonal_decompose
print('all import succeed')
# Out:
# all import succeed

# %%
raw_df = pd.read_csv('E:\Columbia University\Courses\Big-Data Analytics\listings.csv')
print(f"Import {len(raw_df)} Airbnb listings")
# Out:
# Import 37713 Airbnb listings
# C:\Users\51370\anaconda3\envs\bigdata\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (67) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pd.set_option('display.max_columns', len(raw_df.columns)) # To view all columns
pd.set_option('display.max_rows', 100)
raw_df.head(3)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20211102175544   2021-11-03
# 1  3831  https://www.airbnb.com/rooms/3831  20211102175544   2021-11-03
# 2  5121  https://www.airbnb.com/rooms/5121  20211102175544   2021-11-03
#
#                                                 name  \
# 0                              Skylit Midtown Castle
# 1  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                    BlissArtsSpace!
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Enjoy 500 s.f. top floor in 1899 brownstone, w...
# 2  <b>The space</b><br />HELLO EVERYONE AND THANK...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1  Just the right mix of urban center and local n...
# 2                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845
# 1  https://a0.muscache.com/pictures/e49999c2-9fd5...     4869
# 2  https://a0.muscache.com/pictures/2090980c-b68e...     7356
#
#                                  host_url    host_name  host_since  \
# 0  https://www.airbnb.com/users/show/2845     Jennifer  2008-09-09
# 1  https://www.airbnb.com/users/show/4869  LisaRoxanne  2008-12-07
# 2  https://www.airbnb.com/users/show/7356        Garon  2009-02-03
#
#                        host_location  \
# 0  New York, New York, United States
# 1  New York, New York, United States
# 2  New York, New York, United States
#
#                                           host_about  host_response_time  \
# 0  A New Yorker since 2000! My passion is creatin...  a few days or more
# 1  Laid-back Native New Yorker (formerly bi-coast...  a few days or more
# 2   I am an artist(painter, filmmaker) and curato...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                35%                  18%                 f
# 1                21%                  76%                 f
# 2               100%                 100%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/50fc5...
# 1  https://a0.muscache.com/im/users/4869/profile_...
# 2  https://a0.muscache.com/im/pictures/user/72a61...
#
#                                     host_picture_url  host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/50fc5...             Midtown
# 1  https://a0.muscache.com/im/users/4869/profile_...        Clinton Hill
# 2  https://a0.muscache.com/im/pictures/user/72a61...  Bedford-Stuyvesant
#
#    host_listings_count  host_total_listings_count  \
# 0                  8.0                        8.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 1  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 2  ['email', 'phone', 'facebook', 'reviews', 'off...                    t
#
#   host_identity_verified                      neighbourhood  \
# 0                      t            New York, United States
# 1                      t  Brooklyn, New York, United States
# 2                      t                                NaN
#
#   neighbourhood_cleansed neighbourhood_group_cleansed  latitude  longitude  \
# 0                Midtown                    Manhattan  40.75356  -73.98559
# 1     Bedford-Stuyvesant                     Brooklyn  40.68494  -73.95765
# 2     Bedford-Stuyvesant                     Brooklyn  40.68535  -73.95512
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0           Entire rental unit  Entire home/apt             1        NaN
# 1           Entire guest suite  Entire home/apt             3        NaN
# 2  Private room in rental unit     Private room             2        NaN
#
#   bathrooms_text  bedrooms  beds  \
# 0         1 bath       NaN   1.0
# 1         1 bath       1.0   3.0
# 2            NaN       1.0   1.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Bathtub", "Dedicated workspace", "Hair dryer...  $150.00              30
# 1  ["Microwave", "Oven", "Pack \u2019n play/Trave...   $73.00               1
# 2  ["Long term stays allowed", "Heating", "Wifi",...   $60.00              30
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                    30.0                    30.0
# 1             730                     1.0                     1.0
# 2             730                    30.0                    30.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                  1125.0                  1125.0                    30.0
# 1                   730.0                   730.0                     1.0
# 2                   730.0                   730.0                    30.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t                0
# 1                   730.0               NaN                t                4
# 2                   730.0               NaN                t               30
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               17               47               322            2021-11-03
# 1               10               33               220            2021-11-03
# 2               60               90               365            2021-11-03
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 48                      0                       0
# 1                408                     38                       0
# 2                 50                      0                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2009-11-21  2019-11-04                  4.70                    4.72
# 1   2015-01-05  2021-06-29                  4.46                    4.59
# 2   2014-01-22  2016-06-05                  4.52                    4.22
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.62                   4.76
# 1                       4.50                   4.79
# 2                       4.09                   4.91
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.79                    4.86                 4.41
# 1                         4.81                    4.72                 4.65
# 2                         4.91                    4.47                 4.52
#
#   license instant_bookable  calculated_host_listings_count  \
# 0     NaN                f                               3
# 1     NaN                f                               1
# 2     NaN                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            3
# 1                                            1
# 2                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.33
# 1                                            0               4.91
# 2                                            0               0.53

# %% [markdown]
# ### Drop unused feature columns

# %%
drop_features = ['listing_url', 'scrape_id', 'last_scraped', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_id', 'host_url', 'host_name', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'calendar_last_scraped']
df = raw_df.drop(drop_features, axis=1)

# %%
df.isna().sum()
# Out:
# id                                                  0
# host_since                                         31
# host_response_time                              17058
# host_response_rate                              17058
# host_acceptance_rate                            16354
# host_is_superhost                                  31
# host_listings_count                                31
# host_total_listings_count                          31
# host_has_profile_pic                               31
# host_identity_verified                             31
# neighbourhood                                   15206
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                        0
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                       37713
# bathrooms_text                                    111
# bedrooms                                         3961
# beds                                             2249
# amenities                                           0
# price                                               0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                             19
# maximum_minimum_nights                             19
# minimum_maximum_nights                             19
# maximum_maximum_nights                             19
# minimum_nights_avg_ntm                             19
# maximum_nights_avg_ntm                             19
# calendar_updated                                37713
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# first_review                                     9212
# last_review                                      9212
# review_scores_rating                             9213
# review_scores_accuracy                           9834
# review_scores_cleanliness                        9823
# review_scores_checkin                            9841
# review_scores_communication                      9830
# review_scores_location                           9845
# review_scores_value                              9845
# license                                         37712
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                9212
# dtype: int64

# %%
df.drop(['host_acceptance_rate', 'neighbourhood_group_cleansed', 'license'], axis=1, inplace=True)
df.set_index('id', inplace=True)

# %%
print(sum((df.host_listings_count == df.host_total_listings_count) == False))
df.loc[((df.host_listings_count == df.host_total_listings_count) == False)][:5]
# Out:
# 31
#         host_since host_response_time host_response_rate host_is_superhost  \
# id
# 2835711        NaN                NaN                NaN               NaN
# 4446862        NaN                NaN                NaN               NaN
# 4763327        NaN                NaN                NaN               NaN
# 6360224        NaN                NaN                NaN               NaN
# 6992973        NaN                NaN                NaN               NaN
#
#          host_listings_count  host_total_listings_count host_has_profile_pic  \
# id
# 2835711                  NaN                        NaN                  NaN
# 4446862                  NaN                        NaN                  NaN
# 4763327                  NaN                        NaN                  NaN
# 6360224                  NaN                        NaN                  NaN
# 6992973                  NaN                        NaN                  NaN
#
#         host_identity_verified                      neighbourhood  \
# id
# 2835711                    NaN            New York, United States
# 4446862                    NaN  Brooklyn, New York, United States
# 4763327                    NaN  Brooklyn, New York, United States
# 6360224                    NaN                                NaN
# 6992973                    NaN  Brooklyn, New York, United States
#
#         neighbourhood_cleansed  latitude  longitude  \
# id
# 2835711      Greenwich Village  40.73058  -74.00070
# 4446862          Crown Heights  40.67605  -73.95997
# 4763327             Greenpoint  40.72119  -73.95279
# 6360224               Bushwick  40.69977  -73.92912
# 6992973           Williamsburg  40.71944  -73.95645
#
#                        property_type        room_type  accommodates  \
# id
# 2835711           Entire rental unit  Entire home/apt             3
# 4446862  Private room in rental unit     Private room             2
# 4763327           Entire rental unit  Entire home/apt             4
# 6360224  Private room in rental unit     Private room             1
# 6992973           Entire rental unit  Entire home/apt             4
#
#          bathrooms bathrooms_text  bedrooms  beds  \
# id
# 2835711        NaN         1 bath       1.0   2.0
# 4446862        NaN         1 bath       1.0   1.0
# 4763327        NaN         1 bath       1.0   2.0
# 6360224        NaN        0 baths       1.0   1.0
# 6992973        NaN        2 baths       2.0   1.0
#
#                                                  amenities    price  \
# id
# 2835711  ["Stove", "Dedicated workspace", "Hair dryer",...  $106.00
# 4446862  ["Long term stays allowed", "TV", "Heating", "...   $50.00
# 4763327  ["Long term stays allowed", "Cable TV", "Hot t...  $195.00
# 6360224  ["Long term stays allowed", "Heating", "Wifi",...   $37.00
# 6992973  ["Long term stays allowed", "Shampoo", "Fire e...  $145.00
#
#          minimum_nights  maximum_nights  minimum_minimum_nights  \
# id
# 2835711              30            1125                    30.0
# 4446862              30            1125                    30.0
# 4763327              30            1125                    30.0
# 6360224              30            1125                    30.0
# 6992973              30            1125                    30.0
#
#          maximum_minimum_nights  minimum_maximum_nights  \
# id
# 2835711                    30.0                  1125.0
# 4446862                    30.0                  1125.0
# 4763327                    30.0                  1125.0
# 6360224                    30.0                  1125.0
# 6992973                    30.0                  1125.0
#
#          maximum_maximum_nights  minimum_nights_avg_ntm  \
# id
# 2835711                  1125.0                    30.0
# 4446862                  1125.0                    30.0
# 4763327                  1125.0                    30.0
# 6360224                  1125.0                    30.0
# 6992973                  1125.0                    30.0
#
#          maximum_nights_avg_ntm  calendar_updated has_availability  \
# id
# 2835711                  1125.0               NaN                t
# 4446862                  1125.0               NaN                t
# 4763327                  1125.0               NaN                t
# 6360224                  1125.0               NaN                t
# 6992973                  1125.0               NaN                t
#
#          availability_30  availability_60  availability_90  availability_365  \
# id
# 2835711               10               12               16               169
# 4446862                0                0                0                 0
# 4763327                0                0                0                 0
# 6360224                0                0                0                 0
# 6992973                0                0                0                 0
#
#          number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# id
# 2835711                 48                      4                       0
# 4446862                  0                      0                       0
# 4763327                  1                      0                       0
# 6360224                  1                      0                       0
# 6992973                  0                      0                       0
#
#         first_review last_review  review_scores_rating  \
# id
# 2835711   2018-11-24  2021-07-31                  4.46
# 4446862          NaN         NaN                   NaN
# 4763327   2015-10-20  2015-10-20                  4.00
# 6360224   2015-07-01  2015-07-01                  0.00
# 6992973          NaN         NaN                   NaN
#
#          review_scores_accuracy  review_scores_cleanliness  \
# id
# 2835711                    4.63                       3.75
# 4446862                     NaN                        NaN
# 4763327                    4.00                       5.00
# 6360224                     NaN                        NaN
# 6992973                     NaN                        NaN
#
#          review_scores_checkin  review_scores_communication  \
# id
# 2835711                   4.85                         4.92
# 4446862                    NaN                          NaN
# 4763327                   5.00                         4.00
# 6360224                    NaN                          NaN
# 6992973                    NaN                          NaN
#
#          review_scores_location  review_scores_value instant_bookable  \
# id
# 2835711                    4.92                 4.52                f
# 4446862                     NaN                  NaN                f
# 4763327                    5.00                 4.00                f
# 6360224                     NaN                  NaN                f
# 6992973                     NaN                  NaN                f
#
#          calculated_host_listings_count  \
# id
# 2835711                               1
# 4446862                               1
# 4763327                               1
# 6360224                               1
# 6992973                               1
#
#          calculated_host_listings_count_entire_homes  \
# id
# 2835711                                            1
# 4446862                                            0
# 4763327                                            1
# 6360224                                            0
# 6992973                                            1
#
#          calculated_host_listings_count_private_rooms  \
# id
# 2835711                                             0
# 4446862                                             1
# 4763327                                             0
# 6360224                                             1
# 6992973                                             0
#
#          calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 2835711                                            0               1.34
# 4446862                                            0                NaN
# 4763327                                            0               0.01
# 6360224                                            0               0.01
# 6992973                                            0                NaN

# %%
df.drop(['host_total_listings_count', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms'], axis=1, inplace=True)

# %%
lat_long = df[['latitude', 'longitude']]

# %%
df.drop(['latitude', 'longitude', 'neighbourhood'], axis=1, inplace=True)

# %%
sum((df.minimum_nights == df.minimum_minimum_nights) == False)
# Out:
# 1520

# %%
df.drop(['minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm'], axis=1, inplace=True)

# %%
# Replacing columns with f/t with 0/1
df.replace({'f': 0, 't': 1}, inplace=True)

# Plotting the distribution of numerical and boolean categories
df.hist(figsize=(20,20));

# %% [markdown]
# ### Description of each column:
# - experiences_offered - slightly unclear as it does not appear to directly relate to Airbnb Experiences, but this seems to be the main recommended category of travel type, e.g. business
# - host_since - date that the host first joined Airbnb
# - host_response_time - average amount of time the host takes to reply to messages
# - host_response_rate - proportion of messages that the host replies to
# - host_is_superhost - whether or not the host is a superhost, which is a mark of quality for the top-rated and most experienced hosts, and can increase your search ranking on Airbnb
# - host_listings_count - how many listings the host has in total
# - host_identity_verified - whether or not the host has been verified with id
# - neighbourhood_cleansed - the London borough the property is in
# - property_type - type of property, e.g. house or flat
# - room_type - type of listing, e.g. entire home, private room or shared room
# - accommodates - how many people the property accommodates
# - bathrooms - number of bathrooms
# - bedrooms - number of bedrooms
# - beds - number of beds
# - bed_type - type of bed, e.g. real bed or sofa-bed
# - amenities - list of amenities
# - price - nightly advertised price (the target variable)
# - security_deposit - the amount required as a security deposit
# - cleaning_fee - the amount of the cleaning fee (a fixed amount paid per booking)
# - guests_included - the number of guests included in the booking fee
# - extra_people - the price per additional guest above the guests_included price
# - minimum_nights - the minimum length of stay
# - maximum_nights - the maximum length of stay
# - calendar_updated - when the host last updated the calendar
# - availability_30 - how many nights are available to be booked in the next 30 days
# - availability_60 - how many nights are available to be booked in the next 60 days
# - availability_90 - how many nights are available to be booked in the next 90 days
# - availability_365 - how many nights are available to be booked in the next 365 days
# - number_of_reviews - the number of reviews left for the property
# - number_of_reviews_ltm - the number of reviews left for the property in the last twelve months
# - first_review - the date of the first review
# - last_review - the date of the most recent review
# - review_scores_rating - guests can score properties overall from 1 to 5 stars
# - review_scores_accuracy - guests can score the accuracy of a property's description from 1 to 5 stars
# - review_scores_cleanliness - guests can score a property's cleanliness from 1 to 5 stars
# - review_scores_checkin - guests can score their check-in from 1 to 5 stars
# - review_scores_communication - guests can score a host's communication from 1 to 5 stars
# - review_scores_location - guests can score a property's location from 1 to 5 stars
# - review_scores_value - guests can score a booking's value for money from 1 to 5 stars
# - instant_bookable - whether or not the property can be instant booked (i.e. booked straight away, without having to - message the host first and wait to be accepted)
# - cancellation_policy - the type of cancellation policy, e.g. strict or moderate
# - reviews_per_month - calculated field of the average number of reviews left by guest each month

# %% [markdown]
# ### Clean specific columns

# %%
df.amenities[:1].values
# Out:
# array(['["Bathtub", "Dedicated workspace", "Hair dryer", "Fire extinguisher", "TV", "Carbon monoxide alarm", "Dishes and silverware", "Keypad", "Free street parking", "Hot water", "Essentials", "Paid parking off premises", "Luggage dropoff allowed", "Ethernet connection", "Long term stays allowed", "Cleaning before checkout", "Smoke alarm", "Kitchen", "Refrigerator", "Cooking basics", "Coffee maker", "Bed linens", "Stove", "Hangers", "Oven", "Iron", "Wifi", "Extra pillows and blankets", "Air conditioning", "Baking sheet", "Heating"]'],
#       dtype=object)

# %%
# Replacing categories that are types of houses or apartments
df.property_type.replace({
    'Townhouse': 'House',
    'Serviced apartment': 'Apartment',
    'Loft': 'Apartment',
    'Bungalow': 'House',
    'Cottage': 'House',
    'Villa': 'House',
    'Tiny house': 'House',
    'Earth house': 'House',
    'Chalet': 'House'  
    }, inplace=True)

# Replacing other categories with 'other'
df.loc[~df.property_type.isin(['House', 'Apartment']), 'property_type'] = 'Other'

# %%
for col in ['bathrooms', 'bedrooms', 'beds']:
    df[col].fillna(df[col].median(), inplace=True)

# %%
# Creating a set of all possible amenities
amenities_list = list(df.amenities)
amenities_list_string = " ".join(amenities_list)
amenities_list_string = amenities_list_string.replace('{', '')
amenities_list_string = amenities_list_string.replace('}', ',')
amenities_list_string = amenities_list_string.replace('] [', '')
amenities_list_string = amenities_list_string.replace('\\', '')
amenities_list_string = amenities_list_string.replace(' u2013', '')
amenities_list_string = amenities_list_string.replace('"', '')
amenities_set = [x.strip() for x in amenities_list_string.split(',')]
amenities_set = set(amenities_set)
amenities_set
# Out:
# {'Silver',
#  'vo5 body soap',
#  'Klorane shampoo',
#  'PianoHot water',
#  'Beach essentials',
#  'not bedroom sound system with aux',
#  'and deskDedicated workspace',
#  'HeatingFreezer',
#  'EssentialsLong term stays allowedCarbon monoxide alarm',
#  'HangersSmart lock',
#  'Fast wifi 62 Mbps',
#  'LG stove',
#  'KENMOORE oven',
#  'Central heatingHeating',
#  'HeatingBreakfast buffet available u2014 $19 per person per day',
#  'HeatingHDTV with Amazon Prime Video',
#  'HangersKeypad',
#  'Dedicated workspace: office chair and table',
#  'Laundromat nearbyBody soap',
#  'V05 shampoo',
#  'Fireplace guards',
#  'HeatingFrigidaire refrigerator',
#  "Burt's Bees shampoo",
#  'Avanti  refrigerator',
#  'Wifi 216 Mbps',
#  'TV with standard cableFree parking on premises',
#  'Paid washer',
#  'Childrenu2019s books and toys for ages 0-2 years oldMicrowave',
#  "Kiehl's conditioner",
#  'Dr bronners  body soap',
#  '16 TV with Apple TV',
#  'WasherHair dryer',
#  'Paid washer In unit',
#  'ToasterFreezer',
#  'EssentialsWifi 498 Mbps',
#  'Iron55 HDTV',
#  'Geneva Guild toiletries',
#  'Stove',
#  'Record playerHeating',
#  'KeypadClothing storage',
#  'Bose Bluetooth sound system',
#  'Pureology and some organic brands  conditioner',
#  'PoolMicrowave',
#  'LockboxTV',
#  'WifiPrivate entrance',
#  '32 HDTV with Amazon Prime Video',
#  '32 HDTV with Roku',
#  'Roku Bluetooth sound system',
#  'Molton Brown body soap',
#  '40 HDTV',
#  'HeatingWifi',
#  'Baking sheetMicrowave',
#  'LG Soundbar Bluetooth sound system',
#  'Dryer In buildingDedicated workspace',
#  'StoveLock on bedroom door',
#  'Olay Ultra Moisture Plus Body Wash body soap',
#  'Keurig coffee machineBBQ grill',
#  'Host greets youBathtub',
#  'Electric stove',
#  'KeypadBBQ grill',
#  'HeatingGym',
#  'Frigidaire electric Cook top stove',
#  'Baking sheetWifi',
#  'boombox radio w/CD sound system',
#  'IronTV with Apple TV',
#  'HangersMicrowave',
#  'Silkience body soap',
#  'Dishes and silverwareCleaning products',
#  "Jason's conditioner",
#  'Dishes and silverwareMicrowave',
#  'Fructis conditioner',
#  'Mixed  conditioner',
#  'Security cameras on propertyHot water kettle',
#  'Bose sound system',
#  'four burner gas cooktop gas stove',
#  'LG smart Tech refrigerator',
#  'IronSecurity cameras on propertyBaby safety gates',
#  'Tea Tree  shampoo',
#  'Generic electric stove',
#  'Eco shampoo',
#  'Clothing storage: walk-in closet and closetLong term stays allowed',
#  'First aid kitLong term stays allowed',
#  'WasherShared patio or balcony',
#  "Johnson's conditioner",
#  'Building staffDryer',
#  'Cooking basicsGym',
#  '43 HDTV',
#  'Variety  conditioner',
#  'Fitness center',
#  'IronBackyard',
#  '46 HDTV with Amazon Prime Video',
#  '75 HDTV with Roku',
#  'First aid kitDedicated workspace',
#  'HeatingLong term stays allowedLock on bedroom door',
#  'Outdoor dining areaKitchen',
#  'Fisher & Paykel refrigerator',
#  'Long term stays allowedBBQ grill',
#  '36 HDTV with standard cableHeating',
#  'Frigidaire refrigerator',
#  'For sensitive skin body soap',
#  '43 HDTV with premium cable',
#  'Mini Fridge with Freezer refrigerator',
#  'Suave or similar shampoo',
#  '50 TV',
#  'Carious shampoo',
#  'Gas oven with stove  oven',
#  'steal gas stove',
#  'Google home Bluetooth sound system',
#  'EssentialsEV charger',
#  '55 HDTV with Apple TV',
#  'Outdoor dining areaBaby safety gates',
#  'Fire extinguisherElevator',
#  'Board games',
#  'Wifi 700 Mbps',
#  'Unknown stove',
#  'Cooking basicsLong term stays allowedBBQ grill',
#  'DS & Durga conditioner',
#  'Pantene etc conditioner',
#  'Ivory products.  conditioner',
#  'Dishes and silverwareHeating',
#  'Dedicated workspace',
#  'Smoke alarmFire extinguisher',
#  'Hard wired Bluetooth with synced sound in each room.  Bluetooth sound system',
#  'Non brand refrigerator',
#  'N/A oven',
#  'Fast wifi 475 Mbps',
#  'Many body soap',
#  'Gas stoveEssentials',
#  'Central heatingPack u2019n play/Travel crib',
#  'Barbecue utensilsCoffee maker',
#  'Coffee makerLong term stays allowed',
#  'dove conditioner',
#  'Game console: Xbox 360 and Xbox One',
#  'Heating75 HDTV with Netflix',
#  'Please donu2019t you plastic in oven  oven',
#  'HangersEssentials',
#  'and Xbox 360',
#  'Daylan  or dove body soap',
#  'Barbecue utensilsCleaning products',
#  'and 5-10 years old',
#  'Essentialsshampoo/conditioner combo shampoo',
#  'Steel Fridigaire refrigerator',
#  'Williamsburg Hotel Brand linens',
#  'Bosch stainless steel gas stove',
#  'First aid kitHDTV with premium cable',
#  '42 TV with Netflix',
#  'Laundromat nearbyCoffee maker',
#  "Dr. Bronner's body soap",
#  'WifiHot water',
#  'Dr. Brennan body soap',
#  'HeatingSonos Bluetooth sound system',
#  'HeatingBackyard',
#  'Dedicated workspace: table and desk',
#  'HeatingIn bedroom refrigerator',
#  'Pantene  conditionerLock on bedroom door',
#  'Induction stove',
#  '37 HDTV with Chromecast',
#  'Security cameras on propertyBBQ grill',
#  'UNIFY Bluetooth sound system',
#  'Central heatingDryer',
#  'amana electric stove',
#  'ToasterLong term stays allowed',
#  'LockboxPrivate entrance',
#  'and others on occassion conditioner',
#  'LockboxHair dryer',
#  'Hot waterFreezer',
#  'Dial body soap',
#  'HangersHDTV with Apple TV',
#  'Central heatingHot tub',
#  'Puracy plant based and natural body soap',
#  'HeatingPrivate garden or backyard',
#  'Cooking basicsDedicated workspace: table',
#  'Dr. Bronners soap body soap',
#  'SONOS Bluetooth sound system',
#  'Burts Bees body soap',
#  'HangersShampoo',
#  'Public goods shampoo',
#  'Paid dryer In buildingDedicated workspace',
#  'Leibher refrigerator',
#  'Kenmore refrigerator',
#  'Tresemme  conditionerBathtub',
#  'No disclosed conditioner',
#  'side by side refrigerator',
#  'IronTV',
#  'Toaster',
#  'Onsite bar u2014 Lobby Bar',
#  'Cooking basicsBody soap',
#  'Fast wifi 539 Mbps',
#  'WifiFreezer',
#  'LockboxBackyard',
#  'Building staffHot water',
#  '44 TV with Amazon Prime Video',
#  'Sub-Zero Freezer Company',
#  'GE stainless steel gas stove',
#  'Smoke alarmElevator',
#  'Free dryer In unitMicrowave',
#  'Fire extinguisherHeating',
#  'Mini Speakers sound system with aux',
#  'gemini Bluetooth sound system',
#  'Free driveway parking on premises 5 spaces',
#  'IronElevator',
#  'Stainless steel refrigerator',
#  'Tresseme  conditioner',
#  'Gas stoveDryer',
#  'Cleaning productsFire extinguisher',
#  'Jergens body soap',
#  'LockboxPaid parking off premises',
#  'Public Goods  body soap',
#  'n/a shampoo',
#  'Organic Bar Soap body soap',
#  'Random conditioner',
#  'Dishes and silverwareHDTV with Amazon Prime Video',
#  '40 TV with premium cable',
#  'Individual bottles for safety shampoo',
#  'Frigidaire electric stove',
#  'sonos Bluetooth sound system',
#  'WasherAir conditioning',
#  '47 HDTV',
#  'EssentialsConditioner',
#  'Japanese Milk soap body soap',
#  'Bath & Body Works. shampoo',
#  'Smoke alarmFire pit',
#  'Board gamesPrivate entrance',
#  '50 HDTV with Netflix',
#  'Wifi 20 Mbps',
#  'Kirkland conditioner',
#  'PoolDedicated workspace',
#  'FreezerFreezer',
#  'Radio sound system',
#  'Gree  conditioner',
#  'HeatingVintage Yamaha  sound system with aux',
#  'First aid kitBaby safety gates',
#  'GE stainless steel electric stove',
#  'Wifi 114 Mbps',
#  'LockboxBathtub',
#  'Fireplace guardsIndoor fireplace',
#  'WasherPortable air conditioning',
#  'Brand to be determined shampoo',
#  'KENMOORE stainless steel gas stove',
#  '47 HDTV with Amazon Prime Video',
#  'Free parking on premisesHair dryer',
#  'IronBBQ grill',
#  'Hair dryerLock on bedroom door',
#  '40 HDTV with HBO Max',
#  'Paid parking on premisesCoffee maker',
#  'Maytag  refrigerator',
#  '40 HDTV with premium cable',
#  'EssentialsClothing storage: closet and wardrobe',
#  'Self-parking u2014 $45/day',
#  'HeatingDrying rack for clothing',
#  '42 HDTV with standard cable',
#  'White-Wesinghouse refrigeratorLong term stays allowed',
#  'Fast wifi 397 Mbps',
#  'Wifi 931 Mbps',
#  'Board gamesCoffee maker',
#  'Fire extinguisherFreezer',
#  'Smaller size  refrigerator',
#  'Grove Collaborative body soapCoffee maker',
#  'TV with Roku',
#  'KitchenHost greets you',
#  'Multiple Brands shampoo',
#  "Dr Bronner's Peppermint Soap body soap",
#  'Private patio or balconyHair dryer',
#  'Maytag stainless steel oven',
#  'Hot plate induction stove',
#  'Dishes and silverwareTV',
#  'Miele Induction  stainless steel induction stove',
#  'Premier; slightly smaller',
#  'HangersLake access',
#  'Babo Botanicals shampoo',
#  'IronChildrenu2019s dinnerware',
#  'Brands vary. body soap',
#  '100% Vegan & Cruelty-Free',
#  '32 TV with HBO Max',
#  'Shower gel',
#  'WasherHousekeeping',
#  'Free street parkingBoard games',
#  'Free parking on premises 2 spaces',
#  'Paid parking lot on premises 1 spaceBathtub',
#  'Window AC unitLong term stays allowed',
#  'Le Remu00e8det conditioner',
#  'Hangers50 HDTV with Apple TV',
#  'Irish Spring',
#  'Public goods conditioner',
#  'Pentene shampoo',
#  'Game console: PS2',
#  'Game consoleCoffee maker',
#  'Free driveway parking on premises 1 space',
#  'BOSE sound system with Bluetooth and aux',
#  'Beats sound system with Bluetooth and aux',
#  'Head and Shoulders 2 in 1 conditioner',
#  'Game console: Xbox 360Dedicated workspace',
#  'TRESemmu00e9 body soap',
#  'Baking sheetKeypad',
#  'table',
#  'Baking sheetCoffee maker',
#  'Renpure Originals Coconut Cream Nourishing Shampoo shampoo',
#  'Security cameras on propertyDedicated workspace',
#  'Frigidaire stainless steel gas stoveLong term stays allowed',
#  'Air conditioningPack u2019n play/Travel crib',
#  'Game console: PS3 and PS4',
#  'DOVE shampoo',
#  'WasherPrivate gym in building',
#  'lihljkhkljhklj shampoo',
#  'General Electric  oven',
#  'Smoke alarmBathtub',
#  'KeypadHeating',
#  "don't know electric stove",
#  'Dedicated workspace: monitor and desk',
#  'IronRoom service',
#  'Radiant heatingLong term stays allowed',
#  '2-burner portable electric stove electric stove',
#  'Dishes and silverwareHot water kettle',
#  'Wine glassesDryer',
#  'Kitchenette',
#  'TV with Chromecast',
#  'Paid parking garage off premises',
#  'EssentialsLong term stays allowedLong term stays allowed',
#  'Sonos sound system with aux',
#  'HeatingBed linens',
#  'BAR body soap',
#  'hot plate induction stove',
#  'Wifi available u2014 $14/day',
#  'Alba body soap',
#  'HeatingSony sound system with aux',
#  'Verb shampoo',
#  'Vizio sound system with Bluetooth and aux',
#  'Air conditioningBed linens',
#  'Building staff55 HDTV',
#  'Wifi 870 Mbps',
#  'olay body soap',
#  'Cable TVBBQ grill',
#  'Free dryer In buildingIndoor fireplace',
#  '46 HDTV with HBO Max',
#  'Sound Bar Bluetooth sound system',
#  'GE Professional Brand refrigerator',
#  'Caress Body Silk Bars body soap',
#  'Salerm conditioner',
#  'Cleaning before checkoutHeating',
#  'HeatingGame console',
#  'Wifi 100 MbpsIndoor fireplace',
#  'Cooked-to-order breakfast available for a fee',
#  'Game consoleAir conditioning',
#  'Public Goods body soapEV charger',
#  'Game consoleFreezer',
#  'Air conditioningShared fenced garden or backyard',
#  'Continental breakfast available u2014 $13 per person per day',
#  'Baking sheetHot water kettle',
#  'Wifi 108 Mbps',
#  'Apple TV',
#  'Dedicated workspaceLong term stays allowed',
#  'ElevatorHeating',
#  '65 HDTV with HBO Max',
#  'Dispenser for shampoo & bodywash in shower shampoo',
#  'Wifi 82 Mbps',
#  'GE full size refrigerator',
#  'Fast wifi 462 Mbps',
#  'Public Goods body soapLong term stays allowed',
#  'Sound system',
#  'WasherCarbon monoxide alarm',
#  'HeatingTV with Chromecast',
#  'EssentialsShared fenced garden or backyard',
#  'HeatingChildrenu2019s books and toys',
#  'Keurig coffee machineFree dryer In unit',
#  'Air conditioningLong term stays allowedBathtub',
#  'Shared hot tub',
#  'Central heatingOven',
#  'shower gel body soap',
#  'EV charger',
#  'LockboxFree dryer In unit',
#  'StoveHot tub',
#  'HangersStove',
#  'American Range gas stove',
#  'Shared poolHair dryer',
#  'Head and shoulder  conditioner',
#  'TV with standard cableCooking basics',
#  'OGM free  body soap',
#  'HeatingSound system with aux',
#  'IronStainless steel oven',
#  '32 TV with premium cable',
#  'head and shoulder shampoo',
#  'HeatingPrivate entrance',
#  'Game console: PS4 and Xbox 360',
#  'HeatingHeating',
#  'sauve body soap',
#  'Gaggenau stainless steel oven',
#  'HeatingWifi 667 Mbps',
#  '40 HDTV with Apple TV',
#  'Vizio Sound Bar Bluetooth sound system',
#  'Bluetooth sound system',
#  'Lux body soap',
#  'Fire extinguisherLong term stays allowed',
#  'ToasterOven',
#  'Organics conditioner',
#  'Nespresso machine',
#  'Kitchen Aid Profesional stainless steel oven',
#  'Shea Moisture  body soap',
#  'changes body soap',
#  'Fridgidare stainless steel gas stove',
#  'Dual Control Infrared Cooktop',
#  'Pocket wifiDedicated workspace',
#  'Gas stoveHost greets you',
#  'IronBed linens',
#  '44 HDTV with Amazon Prime Video',
#  'IronRoom-darkening shades',
#  'GE refrigerator',
#  'Puracy plant based and natural conditioner',
#  'Netflix',
#  'HeatingHOT PLATE induction stove',
#  'EssentialsBaby safety gates',
#  'HeatingLong term stays allowedBBQ grill',
#  'Dove bar body soap',
#  'Barbecue utensilsMicrowave',
#  'First aid kitAir conditioning',
#  'Ivory body soap',
#  'Private patio or balconyDedicated workspace',
#  'Breck shampoo',
#  'Paid parking lot on premises',
#  'Welcome to use the gas fired stove. gas stove',
#  'Bottled water',
#  'Caress',
#  '46 HDTV with premium cable',
#  'Fire extinguisherPrivate entrance',
#  'Free dryer In unitBathtub',
#  'Free dryer In unitLock on bedroom door',
#  'and dresser',
#  'Air conditioningBody soap',
#  'no name oven',
#  'Tropical Island conditioner',
#  'Frigidaire  gas stove',
#  'ToasterBackyard',
#  'Cooking basicsLong term stays allowed',
#  'bath and body work conditioner',
#  'Board gamesDedicated workspace',
#  'Kitchenaid stainless steel gas stove',
#  'mini fridge  refrigerator',
#  'Sonos',
#  '55 HDTV with standard cable',
#  'Samsung oven',
#  'IronFree dryer In unit',
#  'Private gym',
#  'Speaker Bluetooth sound system',
#  'Shared poolBathtub',
#  'Shampoo shampoo',
#  'Continental breakfast available u2014 $15 per person per day',
#  'Wifi 1024 Mbps',
#  'WasherMosquito net',
#  'William Roam body soap',
#  'LockboxFree parking on premises',
#  'HeatingBread maker',
#  'Samsung Microwave/Convection/Air fryer stainless steel oven',
#  'Samsung refrigerator',
#  'KitchenWasher',
#  'Public goods  shampoo',
#  'HangersFreezer',
#  'and Xbox Series X',
#  'Paid parking on premisesAir conditioning',
#  'Clothing storageLock on bedroom door',
#  'Game consoleLock on bedroom door',
#  'Complimentary continental breakfast',
#  'TBD body soap',
#  '80 HDTV with Netflix',
#  'Echo sound system',
#  'Game console: Nintendo Wii and PS4',
#  'ShampooBathtub',
#  'Game console: Nintendo Wii',
#  'Gym',
#  'Costco body soap',
#  'Self-parking u2014 $35/day',
#  'Dove O Dial conditioner',
#  'ShampooHangers',
#  'KeypadHair dryer',
#  'HeatingWindow AC unit',
#  'Head & Shoulders shampoo',
#  'Keurig coffee machineHangers',
#  'Pantene Pro V conditioner',
#  'GE newly replaced in 2020 oven',
#  'Usually Trader Joeu2019s Tea Tree Tingle body soap',
#  'No disclosed oven',
#  'First aid kitTV',
#  'antibacterial soap for hands and premises are sterile. Please contact me for more detailed information on cleaning and sterilizing. body soap',
#  'Emerson refrigerator',
#  'VIZIO V21 sound system with Bluetooth and aux',
#  'EssentialsElevator',
#  'The best only body soap',
#  'walk-in closet',
#  'Ren Family sulfate free body wash & Personal Bar soap is provided body soap',
#  'General  conditioner',
#  '49 HDTV with Netflix',
#  'Wifi 196 Mbps',
#  'Fire extinguisherHost greets you',
#  'Non Brand gas stove',
#  'Gas stoveHair dryer',
#  '37 TV with Netflix',
#  'TV with standard cableDedicated workspace: table',
#  'Wifi 340 Mbps',
#  'Sun Bum shampoo',
#  'Private hot tubDedicated workspace',
#  'Dishwasher',
#  'Frigidaire  oven',
#  'Amana stainless steel oven',
#  'Building staffSmoke alarm',
#  'Small Travel Size body soap',
#  'Apple HomePod (Apple Devices Only) and portable JBL bluetooth speaker  Bluetooth sound system',
#  'Private patio or balconyLock on bedroom door',
#  'First aid kitBed linens',
#  'HangersLong term stays allowedBathtub',
#  'EssentialsSmall Travel Size conditioner',
#  'Liquid soap  body soap',
#  'and closetCoffee maker',
#  'Dove (original sent) body soap',
#  'Viking 6-burner stainless steel gas stove',
#  'stainless steel electric stove',
#  'HeatingPuracy or Jr Watkins body soap',
#  'We provide a portable gas stove in our kitchenette.  gas stove',
#  'In Bathroom (In-Ceiling System) Bluetooth sound system',
#  'Puracy - natural plant based conditioner',
#  'ElevatorDedicated workspace',
#  'Dr.Bonner body soapHot water kettle',
#  'Dr Bronner Soap body soap',
#  'HeatingLong term stays allowed',
#  'IronHDTV with standard cable',
#  'V05 and other varieties. shampoo',
#  'Gas stoveIndoor fireplace',
#  'works great. Gas powered. oven',
#  'Google Smart Speakers Bluetooth sound system',
#  '55 HDTV with premium cable',
#  'FRIGIDAIRE stainless steel gas stove',
#  'Head and Shoulders shampoo',
#  'Unknown  oven',
#  'Products from ECO Sciences body soap',
#  'Bosche stainless steel gas stove',
#  'Fridgidale refrigerator',
#  'High chairMicrowave',
#  'Private patio or balconyAir conditioning',
#  'Le Remu00e8det shampoo',
#  'Building staffKitchen',
#  'Google Bluetooth sound system',
#  'Paid parking on premisesOven',
#  'HeatingClothing storage: closet',
#  'Free parking on premisesDedicated workspace',
#  'IronGym',
#  'DishwasherFreezer',
#  'Ivory liquid body soap  body soap',
#  'Hot water',
#  'Game consoleCleaning products',
#  'Clothing storageCoffee maker',
#  'HangersLong term stays allowedHost greets you',
#  'Fast wifi 172 Mbps',
#  'samsung Bluetooth sound system',
#  'Caress etc body soap',
#  'Gas stovePortable air conditioning',
#  '32 TV',
#  'dove shampoo',
#  'Humankind (plastic-free) conditioner',
#  'Doss Bluetooth sound system',
#  'Indoor fireplace',
#  'EssentialsHair dryer',
#  'Onsite rooftop bar u2014 cloudM',
#  'Popular brand shampoo',
#  'PANTENE conditioner',
#  'Kristin Ess conditioner',
#  'Smoke alarmBaby safety gates',
#  'Bertazzoni stainless steel gas stove',
#  'EssentialsShampoo',
#  'SMEG refrigerator',
#  'Organic shampoo',
#  '65 HDTV with premium cable',
#  'HeatingLong term stays allowedHair dryer',
#  'WasherShampoo',
#  'Gas stoveDedicated workspace',
#  'ElevatorBathtub',
#  'Game console: Nintendo Switch and Xbox Series X',
#  'Paid parking on premisesBed linens',
#  'Frigidaire with Ice Maker refrigerator',
#  'Wifi 327 MbpsDedicated workspace',
#  'Plaine: zero waste',
#  'N/A refrigerator',
#  'Clothing storageFire extinguisher',
#  'Public Goods body soapDedicated workspace',
#  '57 HDTV',
#  'Wifi 160 Mbps',
#  'Suave  shampoo',
#  'Maytag  stove',
#  'LockboxCoffee maker',
#  'Fisher + Paykel refrigerator',
#  'Building staffIndoor fireplace',
#  'frigidaire  refrigerator',
#  'Childrenu2019s books and toys for ages 0-2 years oldOven',
#  'WasherCoffee maker',
#  "Kiehl's Amino Acid Shampoo shampooFreezer",
#  'Wifi 247 Mbps',
#  'HeatingHDTV with standard cable',
#  'Lock on bedroom doorLong term stays allowed',
#  'garnier hair care conditioner',
#  'Long term stays allowedKitchen',
#  'no stainless steel oven',
#  'PianoBackyard',
#  'swivel/jbc Bluetooth sound system',
#  'GE gas stove',
#  'Lake access',
#  'Eco Botanics shampoo',
#  'Trash compactor',
#  'Plaine body wash. Plaine is a zero waste (refillable bottles) all natural ingredients brand. Scent of either: Rosemary Mint Vanilla or Citrus Lavender body soap',
#  'Childrenu2019s books and toys for ages 0-2 years old',
#  'Laundromat nearbyHot tub',
#  'Wifi 78 Mbps',
#  'bose speaker Bluetooth sound system',
#  'No disclosed gas stove',
#  'KitchenOven',
#  'Game consoleLong term stays allowed',
#  'Air conditioningGym',
#  'MONAT VEGAN PREMIUM HAIR PRODUCTS conditioner',
#  'Shared fenced garden or backyard',
#  'Board gamesOven',
#  'LockboxMicrowave',
#  'HangersHot water kettle',
#  'Freezer',
#  'v05 conditioner',
#  'Mosquito net',
#  'Fire extinguisherStove',
#  '65 HDTV with Amazon Prime Video',
#  '43 TV',
#  'Game console: Xbox 360Microwave',
#  'Hot breakfast available u2014 $20 per person per day',
#  'TV with standard cableSafe',
#  'Liquid  body soap',
#  'Bluefire Hotel Supply. Oasis bliss  body soap',
#  'mini refrigerator',
#  'Central heatingBathtub',
#  'varity body soap',
#  'EssentialsLong term stays allowedBathtub',
#  'Game console: PS4 and Xbox One',
#  'and office chairBathtub',
#  'Regular Body Soap body soap',
#  'Unisex premium brand body soap',
#  'Laundromat nearbySeasonal shampoo',
#  'Various brands  conditioner',
#  'Amazon body soap',
#  'Self-parking u2014 $45/stay',
#  'Dedicated workspace: office chair and deskLong term stays allowed',
#  'Private gym in building',
#  'Baking sheetHeating',
#  'Garnier shampoo',
#  'Central heatingCleaning products',
#  'standard cableBathtub',
#  'Ninja Foodi',
#  'Bathtub',
#  'Bosch gas stove',
#  'KeypadAir conditioning',
#  '52 HDTV',
#  'Dishes and silverwarePaid parking off premises',
#  'Game consoleBackyard',
#  'IronGame console',
#  'HeatingKeypad',
#  'Dishes and silverwareLock on bedroom door',
#  'Good One conditioner',
#  'Dedicated workspaceMicrowave',
#  'Edifier sound system with Bluetooth and aux',
#  'Onsite restaurant u2014 Trademark Taste',
#  'Stored in boxes contact if needed.  shampoo',
#  'premium cableDedicated workspace',
#  'Non Brand refrigerator',
#  'Sonos sound system with Bluetooth and aux',
#  'Loreal conditioner',
#  'Free street parkingConditioner',
#  'Amazon Alexa Bluetooth sound system',
#  'HeatingChanging table',
#  'First aid kitMicrowave',
#  'but good sound.  sound system with Bluetooth and aux',
#  'spirit bath soap body soap',
#  'Air conditioningBackyard',
#  'Multiple brands shampoo',
#  'BeeKind - no parabens. Cruelty free. Biodegradable conditioner',
#  'dial/dove/palmolive body soap',
#  'Cleaning productsGarnier Honey & Milk Moisturizing Condtioner conditioner',
#  'EssentialsSmoke alarm',
#  'Pocket wifi',
#  'HeatingLong term stays allowedLong term stays allowed',
#  'Stove stainless steel gas stove',
#  'Samsung Soundbar sound system with Bluetooth and aux',
#  '60 HDTV',
#  'Native',
#  'EssentialsLong term stays allowedBed linens',
#  'Smoke alarmTrash compactor',
#  'TV with standard cableHot water kettle',
#  'Full size Oven and Stove with 4 gas burners oven',
#  'Fire pitCleaning products',
#  'IronHot tub',
#  'Belisso',
#  'Pantene  shampoo',
#  'Google Nest Home Bluetooth sound system',
#  'Standard  body soap',
#  'Wine glassesDedicated workspace',
#  'EssentialsLake access',
#  'Outdoor dining areaFreezer',
#  'Samsung sound system with Bluetooth and aux',
#  'Onsite bar',
#  'Stainless steel oven',
#  'Paid parking off premises',
#  'brands vary shampoo',
#  'best to bring your own',
#  'Frigidaire stainless steel stove',
#  'Pantene and Head & Shoulders shampoo',
#  'Asprey from the Ritz Carlton body soap',
#  'Dishes and silverwareBaby safety gates',
#  'OvenTV',
#  'Dedicated workspace: table',
#  'Clothing storageIndoor fireplace',
#  'Dishes and silverwareLong term stays allowedLong term stays allowed',
#  'Premier stainless steel stove',
#  'suave conditioner',
#  'Maytag  stainless steel oven',
#  'Paid washer In building',
#  'Dryeru00a0In unitFreezer',
#  'Cleaning productsPortable air conditioning',
#  'Aveno body soap',
#  'IronLong term stays allowedLong term stays allowed',
#  'Beko refrigerator',
#  'Wifi 146 Mbps',
#  'Baking sheetSmoke alarm',
#  'Unsure  gas stove',
#  'Apotheke toiletries',
#  'Free parking on premises',
#  'Sound system with Bluetooth and aux',
#  'Amana refrigerator',
#  'RefrigeratorFreezer',
#  '70 HDTV with standard cable',
#  'multiple hotel-size trials of high-end brands body soap',
#  'Variable usually oganic  body soap',
#  'ShampooFree dryer In unit',
#  'WifiLake access',
#  'Building staffBackyard',
#  'Self-parking u2014 $50/stay',
#  'Calphalon stainless steel oven',
#  '40 HDTV with standard cable',
#  'Air conditioning',
#  'Essentials50 HDTV',
#  'Multiple Types conditioner',
#  'whirlpool refrigerator',
#  'HeatingLong term stays allowedOven',
#  '72 TV with Apple TV',
#  'Cleaning productsBed linens',
#  'Conditioner conditioner',
#  'Fridgidare stainless steel oven',
#  'Organic  body soap',
#  'HangersRefrigerator',
#  'Clothing storageHot water kettle',
#  'LockboxFire extinguisher',
#  'HangersTV',
#  'Garnier Fructis conditioner',
#  'Outdoor dining areaPaid parking off premises',
#  'First aid kitShared fenced garden or backyard',
#  'Vo 5 shampoo',
#  'Hair dual fuel stainless steel gas stove',
#  'Local Brands  body soap',
#  'space limited to small items only refrigerator',
#  'Lockbox42 HDTV with Amazon Prime Video',
#  'Aveeno shampooHair dryer',
#  'Bose WaveRadio sound system with aux',
#  'Fast wifi 309 Mbps',
#  'Dove :) body soap',
#  'whirlpool  electric stove',
#  'Gilchrist & Soames toiletriesTV',
#  'FreezerLong term stays allowed',
#  'Sam sang stainless steel gas stove',
#  'TV with standard cableFreezer',
#  'Mini Fridge refrigerator',
#  'Board gamesHost greets you',
#  'Paid dryer In buildingMicrowave',
#  'Pyle  sound system with Bluetooth and aux',
#  'Wifi 503 Mbps',
#  'Barbecue utensils',
#  '34 TV with Amazon Prime Video',
#  'Bose sound system with aux',
#  'RefrigeratorDryer',
#  'All fragrances  body soap',
#  'HangersBathtub',
#  '42 HDTV',
#  'WifiPack u2019n play/Travel crib',
#  '24 HDTV with Chromecast',
#  'Long term stays allowedLong term stays allowed',
#  'IronEV charger',
#  '32 TV with standard cable',
#  'Estate  oven',
#  'Cleaning products',
#  'Fast wifi 94 Mbps',
#  'Tres Seme shampoo',
#  'Wifi 67 Mbps',
#  'Lockbox50 HDTV',
#  'Air conditioningDryer',
#  'Garnier conditioner',
#  'Wifi 52 Mbps',
#  'Cable TV',
#  'KENMORE NEWLY REPLACED 4 Burners and oven. Regular size.  gas stove',
#  'Limited housekeeping u2014 on request',
#  'Wifi 490 Mbps',
#  'Friedrich  conditioner',
#  'TV with standard cableBBQ grill',
#  'Dryeru00a0In unit',
#  'Building staffPrivate entrance',
#  'Castile Soap body soap',
#  'Pool',
#  'Wifi 194 Mbps',
#  'fridgidaire refrigerator',
#  '65 HDTV with standard cable',
#  'Dedicated workspace: monitor and table',
#  'various conditioner',
#  'Air conditioningBathtub',
#  'Bosche stainless steel oven',
#  'Aesop conditioner',
#  'Central heatingBBQ grill',
#  'Onsite bar u2014 The Seville',
#  'HeatingHair dryer',
#  'Ginger Lily Farms shampoo',
#  'Sound bar  Bluetooth sound system',
#  'Building staffShampoo',
#  '32 HDTV with premium cable',
#  'Board gamesHot water kettle',
#  'Mielle shampoo',
#  'HBO Max',
#  'Products from ECO Sciences conditioner',
#  'Free dryer In unit',
#  'Aliya conditioner',
#  'Vermont Soapworks',
#  'IronCO Bigelow toiletries',
#  'Wifi 950 Mbps',
#  '20 TV with standard cableDedicated workspace',
#  'LockboxDedicated workspace: table',
#  'HangersLong term stays allowedLong term stays allowed',
#  'Babysitter recommendations',
#  'Game console: Xbox One',
#  'Google Home Plus Bluetooth TV Speaker Bluetooth sound system',
#  'Game consoleLong term stays allowedLong term stays allowed',
#  'Self-parking u2014 $51/day',
#  'EssentialsClothing storage: closet',
#  'Fire extinguisherFree parking on premises',
#  'Google Home sound system',
#  'Bosch refrigerator',
#  'WasherShea Solutions Deep Moisture Shampoo (paraben-free) shampoo',
#  'KeypadIndoor fireplace',
#  'EssentialsGame console: PS3',
#  'Gel body soap',
#  'no refrigerator',
#  'WifiLong term stays allowedElevator',
#  'Central heatingJBL Charge 4 speaker',
#  'general electric  stainless steel oven',
#  'coconut body soap',
#  'Free parking on premisesTrash compactor',
#  '55 HDTV with Amazon Prime Video',
#  'Dr. Bronner body soap',
#  'Marshall  Bluetooth sound system',
#  'Cooking basicsHeating',
#  'Glass Plate Electric Cooktop',
#  'DOVE  body soap',
#  'Public Goods body soapMicrowave',
#  'Countertop Hotplate electric stove',
#  'Regular body soap',
#  'EssentialsBBQ grill',
#  '50 TV with HBO Max',
#  'Plant based  body soap',
#  'Alberto Vo5 shampoo',
#  'Shared poolDedicated workspace',
#  'Brand new gas stove',
#  "You're welcome to use whatever I'm using  conditioner",
#  '55 HDTV with Roku',
#  'Central heatingFreezer',
#  'KitchenLong term stays allowedLong term stays allowed',
#  '28 TV with Roku',
#  'Wifi 348 Mbps',
#  'regular body soap',
#  'Board gamesHot tub',
#  'TV with standard cablePaid parking off premises',
#  'House bikes',
#  'Cleaning productsDryer',
#  'pantene shampoo',
#  '200 TV',
#  'Host greets youBed linens',
#  'Any  body soap',
#  "Johnson's body soapDedicated workspace",
#  'Dishes and silverwareCoffee maker',
#  'Different Brands conditioner',
#  'Apple HomePod mini sound system with Bluetooth and aux',
#  'High chairLong term stays allowed',
#  'Shea Moisture conditioner',
#  'Dishes and silverwarePrivate entrance',
#  'Valet parking u2014 $45/day',
#  'Spa',
#  'regular shampoo',
#  'Paid dryer In unit',
#  'WasherLong term stays allowed',
#  'Building staff',
#  'Onsite rooftop bar u2014 Make Believe',
#  '84 HDTV with Netflix',
#  'KitchenLock on bedroom door',
#  'Heatingsamsung  sound system',
#  'HeatingHangers',
#  'Free dryer In buildingMicrowave',
#  'THERE IS A CELLING FAN AN A PORTABLE AC IN THE BEDROOM conditioner',
#  'shared refrigerator  refrigerator',
#  'ZeroDerm shampoo',
#  'Wolf stainless steel gas stove',
#  'LockboxBed linens',
#  'KENMOORE refrigerator',
#  'commercial  refrigerator',
#  'Hot point refrigerator',
#  'CO Bigalow shampoo',
#  'Wifi 200 Mbps',
#  'WasherLong term stays allowedDedicated workspace',
#  'Gas stove',
#  '40 HDTV with Roku',
#  'Complimentary water provided refrigerator',
#  'Generic refrigerator',
#  'Unisex premium brand conditioner',
#  'Laundromat nearbyMicrowave',
#  'HeatingWifi 705 Mbps',
#  'Dishes and silverwareChildrenu2019s books and toys for ages 2-5 years old',
#  'Insignia refrigerator',
#  'Bath & Body Works conditioner',
#  'Paid parking on premisesDedicated workspace',
#  'pantene conditioner',
#  'Dishes and silverwareDedicated workspace',
#  'Cable TVHair dryer',
#  'Paid parking on premisesBackyard',
#  'Dove men and women conditioner',
#  'Alba Botanicau00ae Very Emollient Bath and Shower Gel French Lavender body soap',
#  'Free dryer In unitDedicated workspace',
#  'IronCleaning products',
#  'general electric  stove',
#  'Wine glassesElevator',
#  'iPad Air  sound system',
#  'WifiBaby safety gates',
#  'Baby safety gatesHot tub',
#  'Gas stoveBody soap',
#  'Heating10.1 cu. ft. Top Freezer Refrigerator refrigerator',
#  'ElevatorLong term stays allowed',
#  'Bose Surround Speaker System in All Rooms sound system with Bluetooth and aux',
#  'Gym in building',
#  'Window guards',
#  'Maytag stainless steel stove',
#  '72 HDTV',
#  'HeatingDryer',
#  'Tres Somme shampoo',
#  'Google Home Bluetooth sound system',
#  'Fridgeaire refrigerator',
#  'Always different  conditioner',
#  'MAISONOVO conditioner',
#  'Long term stays allowedRoom-darkening shades',
#  'Doss Bluetooth Speaker Bluetooth sound system',
#  'Samsung  gas stove',
#  'Bosu00e9  Bluetooth sound system',
#  'Dedicated workspace: table and office chairDedicated workspace',
#  'ge stove',
#  'Host greets youFreezer',
#  '42 TV with NetflixHot water kettle',
#  'Ge refrigerator',
#  'WasherOven',
#  '35 HDTV with Amazon Prime Video',
#  'Cleaning productsHangers',
#  'EssentialsChildrenu2019s books and toys',
#  'Fast wifi 132 Mbps',
#  'EssentialsFree parking on premises',
#  'Wifi 100 MbpsCoffee maker',
#  'Leibherr refrigerator',
#  'GE - bringing good things to life! refrigerator',
#  'Wifi 282 Mbps',
#  'Fire extinguisherKitchen',
#  'Building staffShared hot tub',
#  'Alberto VO5 shampoo',
#  '49 TV',
#  '75 HDTV with standard cable',
#  'Cooking basicsFree parking on premises',
#  '20 TV',
#  'Galanz refrigerator',
#  'samsung stainless steel oven',
#  'dove',
#  'Onsite bar u2014 Cafe',
#  'First aid kitBathtub',
#  'Cooking basicsCoffee maker',
#  'Body wash and soap body soap',
#  'WasherChildrenu2019s books and toys for ages 2-5 years old',
#  'Fast wifi 209 Mbps',
#  'Melaleuca  shampoo',
#  'HangersShared patio or balcony',
#  'Samsung stainless steel gas stove',
#  'Dr. Bronners body soap',
#  'Samsung  stainless steel oven',
#  'Energy stainless steel oven',
#  'Amanna  refrigerator',
#  'Variations  body soap',
#  'Surround sound Bluetooth sound system',
#  'Private fenced garden or backyardMicrowave',
#  'Spring Floral conditioner',
#  'Garnier Fructis shampoo',
#  'RefrigeratorBathtub',
#  'HeatingBoat slip',
#  'Smoke alarmHot tub',
#  'Outdoor furniture',
#  'Building staffSound system with aux',
#  'Paid parking on premisesIndoor fireplace',
#  ...}

# %%
df.loc[df['amenities'].str.contains('24-hour check-in'), 'check_in_24h'] = 1
df.loc[df['amenities'].str.contains('Air conditioning|Central air conditioning'), 'air_conditioning'] = 1
df.loc[df['amenities'].str.contains('Amazon Echo|Apple TV|Game console|Netflix|Projector and screen|Smart TV'), 'high_end_electronics'] = 1
df.loc[df['amenities'].str.contains('BBQ grill|Fire pit|Propane barbeque'), 'bbq'] = 1
df.loc[df['amenities'].str.contains('Balcony|Patio'), 'balcony'] = 1
df.loc[df['amenities'].str.contains('Beach view|Beachfront|Lake access|Mountain view|Ski-in/Ski-out|Waterfront'), 'nature_and_views'] = 1
df.loc[df['amenities'].str.contains('Bed linens'), 'bed_linen'] = 1
df.loc[df['amenities'].str.contains('Breakfast'), 'breakfast'] = 1
df.loc[df['amenities'].str.contains('TV'), 'tv'] = 1
df.loc[df['amenities'].str.contains('Coffee maker|Espresso machine'), 'coffee_machine'] = 1
df.loc[df['amenities'].str.contains('Cooking basics'), 'cooking_basics'] = 1
df.loc[df['amenities'].str.contains('Dishwasher|Dryer|Washer'), 'white_goods'] = 1
df.loc[df['amenities'].str.contains('Elevator'), 'elevator'] = 1
df.loc[df['amenities'].str.contains('Exercise equipment|Gym|gym'), 'gym'] = 1
df.loc[df['amenities'].str.contains('Family/kid friendly|Children|children'), 'child_friendly'] = 1
df.loc[df['amenities'].str.contains('parking'), 'parking'] = 1
df.loc[df['amenities'].str.contains('Garden|Outdoor|Sun loungers|Terrace'), 'outdoor_space'] = 1
df.loc[df['amenities'].str.contains('Host greets you'), 'host_greeting'] = 1
df.loc[df['amenities'].str.contains('Hot tub|Jetted tub|hot tub|Sauna|Pool|pool'), 'hot_tub_sauna_or_pool'] = 1
df.loc[df['amenities'].str.contains('Internet|Pocket wifi|Wifi'), 'internet'] = 1
df.loc[df['amenities'].str.contains('Long term stays allowed'), 'long_term_stays'] = 1
df.loc[df['amenities'].str.contains('Pets|pet|Cat(s)|Dog(s)'), 'pets_allowed'] = 1
df.loc[df['amenities'].str.contains('Private entrance'), 'private_entrance'] = 1
df.loc[df['amenities'].str.contains('Safe|Security system'), 'secure'] = 1
df.loc[df['amenities'].str.contains('Self check-in'), 'self_check_in'] = 1
df.loc[df['amenities'].str.contains('Smoking allowed'), 'smoking_allowed'] = 1
df.loc[df['amenities'].str.contains('Step-free access|Wheelchair|Accessible'), 'accessible'] = 1
df.loc[df['amenities'].str.contains('Suitable for events'), 'event_suitable'] = 1
# Out:
# C:\Users\51370\AppData\Local\Temp/ipykernel_33432/1426836555.py:22: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df.loc[df['amenities'].str.contains('Pets|pet|Cat(s)|Dog(s)'), 'pets_allowed'] = 1

# %%
# Replacing nulls with zeros for new columns
cols_to_replace_nulls = df.iloc[:,41:].columns
df[cols_to_replace_nulls] = df[cols_to_replace_nulls].fillna(0)

# Produces a list of amenity features where one category (true or false) contains fewer than 10% of listings
infrequent_amenities = []
for col in df.iloc[:,41:].columns:
    if df[col].sum() < len(df)/10:
        infrequent_amenities.append(col)
print(infrequent_amenities)

# Dropping infrequent amenity features
df.drop(infrequent_amenities, axis=1, inplace=True)

# Dropping the original amenity feature
df.drop('amenities', axis=1, inplace=True)
# Out:
# ['high_end_electronics', 'bbq', 'balcony', 'nature_and_views', 'breakfast', 'child_friendly', 'outdoor_space', 'hot_tub_sauna_or_pool', 'pets_allowed', 'secure', 'self_check_in', 'smoking_allowed', 'accessible', 'event_suitable']

# %%
df.columns[40:]
# Out:
# Index(['bed_linen', 'tv', 'coffee_machine', 'cooking_basics', 'white_goods',
#        'elevator', 'gym', 'parking', 'host_greeting', 'internet',
#        'long_term_stays', 'private_entrance'],
#       dtype='object')

# %%
df.price = df.price.str[1:-3]
df.price = df.price.str.replace(",", "")
df.price = df.price.astype('int64')

# %%
df.drop('calendar_updated', axis=1, inplace=True)

# %%
df.drop(['availability_30', 'availability_60', 'availability_365'], axis=1, inplace=True)

# %%
print(f"Null values in 'first_review': {round(100*df.first_review.isna().sum()/len(df),1)}%")
print(f"Null values in 'review_scores_rating': {round(100*df.review_scores_rating .isna().sum()/len(df),1)}%")
# Out:
# Null values in 'first_review': 24.4%
# Null values in 'review_scores_rating': 24.4%

# %%
df.first_review = pd.to_datetime(df.first_review) # Converting to datetime

# Calculating the number of days between the first review and the date the data was scraped
df['time_since_first_review'] = (datetime(2019, 4, 9) - df.first_review).astype('timedelta64[D]')

# %%
# Distribution of the number of days since first review
df.time_since_first_review.hist(figsize=(15,5), bins=30);

# %%
def bin_column(col, bins, labels, na_label='unknown'):
    """
    Takes in a column name, bin cut points and labels, replaces the original column with a
    binned version, and replaces nulls (with 'unknown' if unspecified).
    """
    df[col] = pd.cut(df[col], bins=bins, labels=labels, include_lowest=True)
    df[col] = df[col].astype('str')
    df[col].fillna(na_label, inplace=True)

# %%
# Binning time since first review
bin_column('time_since_first_review',
           bins=[0, 182, 365, 730, 1460, max(df.time_since_first_review)],
           labels=['0-6 months',
                   '6-12 months',
                   '1-2 years',
                   '2-3 years',
                   '4+ years'],
           na_label='no reviews')

# %%
df.last_review = pd.to_datetime(df.last_review) # Converting to datetime

# Calculating the number of days between the most recent review and the date the data was scraped
df['time_since_last_review'] = (datetime(2019, 4, 9) - df.last_review).astype('timedelta64[D]')

# %%
# Distribution of the number of days since last review
df.time_since_last_review.hist(figsize=(15,5), bins=30);

# %%
# Binning time since last review
bin_column('time_since_last_review',
           bins=[0, 14, 60, 182, 365, max(df.time_since_last_review)],
           labels=['0-2 weeks',
                   '2-8 weeks',
                   '2-6 months',
                   '6-12 months',
                   '1+ year'],
           na_label='no reviews')

# %%
# Dropping last_review - first_review will be kept for EDA and dropped later
df.drop('last_review', axis=1, inplace=True)

# %%
# Checking the distributions of the review ratings columns
variables_to_plot = list(df.columns[df.columns.str.startswith("review_scores") == True])
fig = plt.figure(figsize=(12,8))
for i, var_name in enumerate(variables_to_plot):
    ax = fig.add_subplot(3,3,i+1)
    df[var_name].hist(bins=10,ax=ax)
    ax.set_title(var_name)
fig.tight_layout()
plt.show()

# %%
# Creating a list of all review columns that are scored out of 10
variables_to_plot.pop(0)
# Out:
# 'review_scores_rating'

# %%
# Binning for all columns scored out of 10
for col in variables_to_plot:
    bin_column(col,
               bins=[0, 8, 9, 10],
               labels=['0-8/10', '9/10', '10/10'],
               na_label='no reviews')

# %%
# Binning column scored out of 100
bin_column('review_scores_rating',
           bins=[0, 80, 95, 100],
           labels=['0-79/100', '80-94/100', '95-100/100'],
           na_label='no reviews')

# %% [markdown]
# ## Time series data analysis

# %%
def decompose_time_series(df, title=''):
    """
    Plots the original time series and its decomposition into trend, seasonal and residual.
    """
    # Decomposing the time series
    decomposition = seasonal_decompose(df)
    
    # Getting the trend, seasonality and noise
    trend = decomposition.trend
    seasonal = decomposition.seasonal
    residual = decomposition.resid
    
    # Plotting the original time series and the decomposition
    plt.figure(figsize=(12,8))
    plt.suptitle(title, fontsize=14, y=1)
    plt.subplots_adjust(top=0.80)
    plt.subplot(411)
    plt.plot(df, label='Original')
    plt.legend(loc='upper left')
    plt.subplot(412)
    plt.plot(trend, label='Trend')
    plt.legend(loc='upper left')
    plt.subplot(413)
    plt.plot(seasonal,label='Seasonality')
    plt.legend(loc='upper left')
    plt.subplot(414)
    plt.plot(residual, label='Residuals')
    plt.legend(loc='upper left')
    plt.tight_layout()

# %%
ts_host_since = pd.DataFrame(df.set_index('host_since'))

# %%
ts_first_review = pd.DataFrame(df.set_index('first_review'))

# %%
ts_host_since = ts_host_since.rename(columns={0: 'hosts'})
ts_host_since.index.rename('month', inplace=True)
ts_first_review = ts_first_review.rename(columns={0: 'reviews'})
ts_first_review.index.rename('month', inplace=True)

# %%
# List of the largest host_listings_count and the year the host joined Airbnb
df.sort_values('host_listings_count').drop_duplicates('host_listings_count',keep='last').tail(10)[['host_since', 'host_listings_count']]
# Out:
#           host_since  host_listings_count
# id
# 11866751  2015-03-30                401.0
# 19153081  2015-04-14                512.0
# 6117496   2015-04-07                653.0
# 38236827  2015-11-02               1106.0
# 50595904  2020-07-29               1185.0
# 52229417  2016-12-16               1987.0
# 51750623  2020-09-23               2232.0
# 52534282  2013-03-25               3139.0
# 51500571  2018-11-21               4067.0
# 47861526         NaN                  NaN

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df.first_review.dt.year, np.log(df.price))
plt.xlabel('Year that the listing had its first review', fontsize=12)
plt.ylabel('Nightly price (log-transformed)', fontsize=12)
plt.title('Change per year in the nightly price of Airbnb listings', fontsize=16)
plt.show()
# Out:
# C:\Users\51370\anaconda3\envs\bigdata\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\51370\anaconda3\envs\bigdata\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# List of the largest host_listings_count and the year the host joined Airbnb
df.sort_values('host_listings_count').drop_duplicates('host_listings_count',keep='last').tail(10)[['host_since', 'host_listings_count']]
# Out:
#           host_since  host_listings_count
# id
# 11866751  2015-03-30                401.0
# 19153081  2015-04-14                512.0
# 6117496   2015-04-07                653.0
# 38236827  2015-11-02               1106.0
# 50595904  2020-07-29               1185.0
# 52229417  2016-12-16               1987.0
# 51750623  2020-09-23               2232.0
# 52534282  2013-03-25               3139.0
# 51500571  2018-11-21               4067.0
# 47861526         NaN                  NaN

# %%
print("Mean nightly price of listings in each year on Airbnb")
print(round(df.set_index('first_review').price.resample('YS').mean(),2))
# Out:
# Mean nightly price of listings in each year on Airbnb
# first_review
# 2009-01-01    179.33
# 2010-01-01    153.71
# 2011-01-01    196.13
# 2012-01-01    157.71
# 2013-01-01    167.46
# 2014-01-01    155.07
# 2015-01-01    155.75
# 2016-01-01    146.02
# 2017-01-01    136.75
# 2018-01-01    142.60
# 2019-01-01    152.28
# 2020-01-01    177.91
# 2021-01-01    168.82
# Name: price, dtype: float64

# %%
# Dropping host_since and first_review as they are no longer needed
df.drop(['host_since', 'first_review'], axis=1, inplace=True)

# %%
df.describe()
# Out:
#        host_is_superhost  host_listings_count  host_has_profile_pic  \
# count       37682.000000         37682.000000          37682.000000
# mean            0.195133            44.408471              0.993498
# std             0.396308           294.251560              0.080372
# min             0.000000             0.000000              0.000000
# 25%             0.000000             1.000000              1.000000
# 50%             0.000000             1.000000              1.000000
# 75%             0.000000             3.000000              1.000000
# max             1.000000          4067.000000              1.000000
#
#        host_identity_verified  accommodates  bathrooms      bedrooms  \
# count            37682.000000  37713.000000        0.0  37713.000000
# mean                 0.829972      2.784981        NaN      1.287116
# std                  0.375662      1.863980        NaN      0.671743
# min                  0.000000      0.000000        NaN      1.000000
# 25%                  1.000000      2.000000        NaN      1.000000
# 50%                  1.000000      2.000000        NaN      1.000000
# 75%                  1.000000      4.000000        NaN      1.000000
# max                  1.000000     16.000000        NaN     13.000000
#
#                beds         price  minimum_nights  maximum_nights  \
# count  37713.000000  37713.000000    37713.000000    3.771300e+04
# mean       1.555511    165.422560       22.130645    5.866011e+04
# std        1.054040    292.366182       30.809556    1.105915e+07
# min        1.000000      0.000000        1.000000    1.000000e+00
# 25%        1.000000     69.000000        3.000000    6.000000e+01
# 50%        1.000000    110.000000       30.000000    1.125000e+03
# 75%        2.000000    180.000000       30.000000    1.125000e+03
# max       24.000000  10000.000000     1250.000000    2.147484e+09
#
#        has_availability  availability_90  number_of_reviews  \
# count      37713.000000     37713.000000       37713.000000
# mean           0.943468        30.737173          23.233368
# std            0.230950        33.750825          50.153962
# min            0.000000         0.000000           0.000000
# 25%            1.000000         0.000000           1.000000
# 50%            1.000000        18.000000           4.000000
# 75%            1.000000        61.000000          20.000000
# max            1.000000        90.000000        1009.000000
#
#        number_of_reviews_ltm  number_of_reviews_l30d  instant_bookable  \
# count           37713.000000            37713.000000      37713.000000
# mean                4.675576                0.526954          0.268846
# std                14.257903                1.484155          0.443366
# min                 0.000000                0.000000          0.000000
# 25%                 0.000000                0.000000          0.000000
# 50%                 0.000000                0.000000          0.000000
# 75%                 3.000000                0.000000          1.000000
# max               624.000000               69.000000          1.000000
#
#        reviews_per_month  check_in_24h  air_conditioning     bed_linen  \
# count       28501.000000           0.0           31460.0  37713.000000
# mean            1.640820           NaN               1.0      0.375282
# std             4.220807           NaN               0.0      0.484202
# min             0.010000           NaN               1.0      0.000000
# 25%             0.120000           NaN               1.0      0.000000
# 50%             0.470000           NaN               1.0      0.000000
# 75%             1.690000           NaN               1.0      1.000000
# max           136.000000           NaN               1.0      1.000000
#
#                  tv  coffee_machine  cooking_basics   white_goods  \
# count  37713.000000    37713.000000    37713.000000  37713.000000
# mean       0.725559        0.368467        0.444011      0.460345
# std        0.446238        0.482395        0.496862      0.498432
# min        0.000000        0.000000        0.000000      0.000000
# 25%        0.000000        0.000000        0.000000      0.000000
# 50%        1.000000        0.000000        0.000000      0.000000
# 75%        1.000000        1.000000        1.000000      1.000000
# max        1.000000        1.000000        1.000000      1.000000
#
#            elevator           gym       parking  host_greeting      internet  \
# count  37713.000000  37713.000000  37713.000000   37713.000000  37713.000000
# mean       0.240156      0.105879      0.448148       0.122637      0.972927
# std        0.427184      0.307686      0.497311       0.328024      0.162298
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        0.000000      0.000000      0.000000       0.000000      1.000000
# 50%        0.000000      0.000000      0.000000       0.000000      1.000000
# 75%        0.000000      0.000000      1.000000       0.000000      1.000000
# max        1.000000      1.000000      1.000000       1.000000      1.000000
#
#        long_term_stays  private_entrance
# count     37713.000000      37713.000000
# mean          0.918224          0.244796
# std           0.274026          0.429972
# min           0.000000          0.000000
# 25%           1.000000          0.000000
# 50%           1.000000          0.000000
# 75%           1.000000          0.000000
# max           1.000000          1.000000

# %%
plt.figure(figsize=(10,5))
df.price.hist(bins=100, range=(0,1000))
plt.margins(x=0)
plt.axvline(200, color='orange', linestyle='--')
plt.title("Airbnb advertised nightly prices up to $1000", fontsize=16)
plt.xlabel("Price ($)")
plt.ylabel("Number of listings")
plt.show()

# %%
df.loc[df.price <= 10, 'price'] = 10
df.loc[df.price >= 1000, 'price'] = 1000

# %%
print("Median number of listings per host:", int(df.host_listings_count.median()))
print("Mean number of listings per host:", int(round(df.host_listings_count.mean())))
print(f"{int(round(100*len(df[df.host_listings_count == 1])/len(df)))}% of listings are from hosts with one listing.")
# Out:
# Median number of listings per host: 1
# Mean number of listings per host: 44
# 45% of listings are from hosts with one listing.

# %%
plt.figure(figsize=(10,5))
df.groupby('accommodates').price.median().plot(kind='bar')
plt.title('Median price of Airbnbs accommodating different number of guests', fontsize=14)
plt.xlabel('Number of guests accommodated', fontsize=13)
plt.ylabel('Median price ($)', fontsize=13)
plt.xticks(rotation=0)
plt.xlim(left=0.5)
plt.show()

# %%
df[['accommodates', 'bathrooms', 'bedrooms', 'beds']].hist(figsize=(8,6));

# %% [markdown]
# ## Modeling

# %%
transformed_df = pd.get_dummies(df)

# %%
def multi_collinearity_heatmap(df, title, figsize=(11,9)):
    
    """
    Creates a heatmap of correlations between features in the df. A figure size can optionally be set.
    """
    
    # Set the style of the visualization
    sns.set(style="white")

    # Create a covariance matrix
    corr = df.corr()

    # Generate a mask the size of our covariance matrix
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=figsize)
    ax.set_title(title, fontsize=30)

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5}, vmax=corr[corr != 1.0].max().max());

# %%
# multi_collinearity_heatmap(transformed_df, figsize=(20,20))

# %%
# multi_collinearity_heatmap(transformed_df.drop(list(transformed_df.columns[transformed_df.columns.str.startswith('borough')]), axis=1), figsize=(25,22))

# %%
import re

# Dropping collinear features
to_drop = []
regex1 = '^host_response_rate_\\d+%$'
regex2 = '^neighbourhood_cleansed_.+$'
regex3 = '^check_in_.+$'
regex4 = '^time_since_.+$'
for column in transformed_df:
    if re.match(regex1, column) or re.match(regex2, column) or re.match(regex3, column) or re.match(regex4, column):
        to_drop.append(column)
to_drop.extend(list(transformed_df.columns[transformed_df.columns.str.endswith('nan')]))
transformed_df.drop(to_drop, axis=1, inplace=True)

# to_drop = ['host_response_rate_11%', 'host_response_rate_13%', 'host_response_rate_14%', 'host_response_rate_15%', 
#            'host_response_rate_17%', 'host_response_rate_20%', 'host_response_rate_21%', 'host_response_rate_22%', 
#            'host_response_rate_23%', 'host_response_rate_25%', 'host_response_rate_28%', 'host_response_rate_29%', 
#            'host_response_rate_30%', 'host_response_rate_32%', 'host_response_rate_33%', 'host_response_rate_34%', 
#            'host_response_rate_35%', 'host_response_rate_36%', 'host_response_rate_38%', 'host_response_rate_40%', 
#            'host_response_rate_41%', 'host_response_rate_42%', 'host_response_rate_43%', 'host_response_rate_44%', 
#            'host_response_rate_45%', 'host_response_rate_46%', 'host_response_rate_47%', 'host_response_rate_48%', 
#            'host_response_rate_49%', 'host_response_rate_5%', 'host_response_rate_50%', 'host_response_rate_51%', 
#            'host_response_rate_52%', 'host_response_rate_53%', 'host_response_rate_54%', 'host_response_rate_55%', 
#            'host_response_rate_56%', 'host_response_rate_57%', 'host_response_rate_58%', 'host_response_rate_6%', 
#            'host_response_rate_60%', 'host_response_rate_61%', 'host_response_rate_62%', 'host_response_rate_63%', 
#            'host_response_rate_64%', 'host_response_rate_65%', 'host_response_rate_67%', 'host_response_rate_68%', 
#            'host_response_rate_69%', 'host_response_rate_7%', 'host_response_rate_70%', 'host_response_rate_71%', 
#            'host_response_rate_72%', 'host_response_rate_73%', 'host_response_rate_74%', 'host_response_rate_75%', 
#            'host_response_rate_76%', 'host_response_rate_77%', 'host_response_rate_78%', 'host_response_rate_79%', 
#            'host_response_rate_80%', 'host_response_rate_81%', 'host_response_rate_82%', 'host_response_rate_83%', 
#            'host_response_rate_84%', 'host_response_rate_85%', 'host_response_rate_86%', 'host_response_rate_87%', 
#            'host_response_rate_88%', 'host_response_rate_89%', 'host_response_rate_9%', 'host_response_rate_90%', 
#            'host_response_rate_91%', 'host_response_rate_92%', 'host_response_rate_93%', 'host_response_rate_94%', 
#            'host_response_rate_95%', 'host_response_rate_96%', 'host_response_rate_97%', 'host_response_rate_98%', 
#            'host_response_rate_99%', 'neighbourhood_cleansed_Allerton', 'neighbourhood_cleansed_Arden Heights', 
#            'neighbourhood_cleansed_Arrochar', 'neighbourhood_cleansed_Arverne', 'neighbourhood_cleansed_Astoria', 
#            'neighbourhood_cleansed_Bath Beach', 'neighbourhood_cleansed_Battery Park City', 
#            'neighbourhood_cleansed_Bay Ridge', 'neighbourhood_cleansed_Bay Terrace', 
#            'neighbourhood_cleansed_Baychester', 'neighbourhood_cleansed_Bayside', 'neighbourhood_cleansed_Bayswater', 
#            'neighbourhood_cleansed_Bedford-Stuyvesant', 'neighbourhood_cleansed_Belle Harbor', 
#            'neighbourhood_cleansed_Bellerose', 'neighbourhood_cleansed_Belmont', 'neighbourhood_cleansed_Bensonhurst',
#            'neighbourhood_cleansed_Bergen Beach', 'neighbourhood_cleansed_Boerum Hill', 
#            'neighbourhood_cleansed_Borough Park', 'neighbourhood_cleansed_Breezy Point',
#            'neighbourhood_cleansed_Briarwood', 'neighbourhood_cleansed_Brighton Beach', 
#            'neighbourhood_cleansed_Bronxdale', 'neighbourhood_cleansed_Brooklyn Heights', 
#            'neighbourhood_cleansed_Brownsville', "neighbourhood_cleansed_Bull's Head", 
#            'neighbourhood_cleansed_Bushwick', 'neighbourhood_cleansed_Cambria Heights', 'neighbourhood_cleansed_Canarsie', 'neighbourhood_cleansed_Carroll Gardens', 'neighbourhood_cleansed_Castle Hill',
#            'neighbourhood_cleansed_Castleton Corners', 'neighbourhood_cleansed_Chelsea', 'neighbourhood_cleansed_Chelsea, Staten Island', 'neighbourhood_cleansed_Chinatown', 'neighbourhood_cleansed_City Island', 'neighbourhood_cleansed_Civic Center', 'neighbourhood_cleansed_Claremont Village', 
#            'neighbourhood_cleansed_Clason Point', 'neighbourhood_cleansed_Clifton', 'neighbourhood_cleansed_Clinton Hill', 'neighbourhood_cleansed_Co-op City', 'neighbourhood_cleansed_Cobble Hill', 'neighbourhood_cleansed_College Point', 'neighbourhood_cleansed_Columbia St', 'neighbourhood_cleansed_Concord', 'neighbourhood_cleansed_Concourse', 
#            'neighbourhood_cleansed_Concourse Village', 'neighbourhood_cleansed_Coney Island', 'neighbourhood_cleansed_Corona', 'neighbourhood_cleansed_Country Club', 'neighbourhood_cleansed_Crown Heights', 'neighbourhood_cleansed_Cypress Hills', 'neighbourhood_cleansed_DUMBO', 'neighbourhood_cleansed_Ditmars Steinway',
#            'neighbourhood_cleansed_Dongan Hills', 'neighbourhood_cleansed_Douglaston', 'neighbourhood_cleansed_Downtown Brooklyn', 'neighbourhood_cleansed_Dyker Heights', 'neighbourhood_cleansed_East Elmhurst', 'neighbourhood_cleansed_East Flatbush', 'neighbourhood_cleansed_East Harlem', 'neighbourhood_cleansed_East Morrisania', 'neighbourhood_cleansed_East New York', 'neighbourhood_cleansed_East Village', 
#            'neighbourhood_cleansed_Eastchester', 'neighbourhood_cleansed_Edenwald', 'neighbourhood_cleansed_Edgemere', 'neighbourhood_cleansed_Elmhurst', 'neighbourhood_cleansed_Eltingville', 'neighbourhood_cleansed_Emerson Hill', 'neighbourhood_cleansed_Far Rockaway', 'neighbourhood_cleansed_Fieldston', 'neighbourhood_cleansed_Financial District', 'neighbourhood_cleansed_Flatbush', 'neighbourhood_cleansed_Flatiron District', 'neighbourhood_cleansed_Flatlands', 'neighbourhood_cleansed_Flushing',
#            'neighbourhood_cleansed_Fordham', 'neighbourhood_cleansed_Forest Hills', 'neighbourhood_cleansed_Fort Greene', 'neighbourhood_cleansed_Fort Hamilton', 'neighbourhood_cleansed_Fort Wadsworth', 'neighbourhood_cleansed_Fresh Meadows', 'neighbourhood_cleansed_Gerritsen Beach', 'neighbourhood_cleansed_Glendale', 'neighbourhood_cleansed_Gowanus', 'neighbourhood_cleansed_Gramercy', 'neighbourhood_cleansed_Graniteville',
#            'neighbourhood_cleansed_Grant City', 'neighbourhood_cleansed_Gravesend', 'neighbourhood_cleansed_Great Kills', 'neighbourhood_cleansed_Greenpoint', 'neighbourhood_cleansed_Greenwich Village', 'neighbourhood_cleansed_Grymes Hill', 'neighbourhood_cleansed_Harlem', "neighbourhood_cleansed_Hell's Kitchen", 'neighbourhood_cleansed_Highbridge', 'neighbourhood_cleansed_Hollis', 'neighbourhood_cleansed_Holliswood', 'neighbourhood_cleansed_Howard Beach', 'neighbourhood_cleansed_Howland Hook', 'neighbourhood_cleansed_Huguenot', 'neighbourhood_cleansed_Hunts Point', 'neighbourhood_cleansed_Inwood', 
#            'neighbourhood_cleansed_Jackson Heights', 'neighbourhood_cleansed_Jamaica', 'neighbourhood_cleansed_Jamaica Estates', 'neighbourhood_cleansed_Jamaica Hills', 'neighbourhood_cleansed_Kensington', 'neighbourhood_cleansed_Kew Gardens', 'neighbourhood_cleansed_Kew Gardens Hills', 'neighbourhood_cleansed_Kingsbridge', 'neighbourhood_cleansed_Kips Bay', 'neighbourhood_cleansed_Laurelton', 'neighbourhood_cleansed_Lighthouse Hill', 'neighbourhood_cleansed_Little Italy', 'neighbourhood_cleansed_Little Neck', 'neighbourhood_cleansed_Long Island City', 'neighbourhood_cleansed_Longwood', 'neighbourhood_cleansed_Lower East Side', 'neighbourhood_cleansed_Manhattan Beach', 'neighbourhood_cleansed_Marble Hill', 'neighbourhood_cleansed_Mariners Harbor', 'neighbourhood_cleansed_Maspeth', 'neighbourhood_cleansed_Melrose', 'neighbourhood_cleansed_Middle Village', 'neighbourhood_cleansed_Midland Beach', 'neighbourhood_cleansed_Midtown', 'neighbourhood_cleansed_Midwood', 'neighbourhood_cleansed_Mill Basin', 'neighbourhood_cleansed_Morningside Heights', 'neighbourhood_cleansed_Morris Heights', 'neighbourhood_cleansed_Morris Park', 'neighbourhood_cleansed_Morrisania', 'neighbourhood_cleansed_Mott Haven', 'neighbourhood_cleansed_Mount Eden', 'neighbourhood_cleansed_Mount Hope', 'neighbourhood_cleansed_Murray Hill', 'neighbourhood_cleansed_Navy Yard', 'neighbourhood_cleansed_Neponsit', 'neighbourhood_cleansed_New Brighton', 'neighbourhood_cleansed_New Dorp', 'neighbourhood_cleansed_New Dorp Beach', 'neighbourhood_cleansed_New Springville', 'neighbourhood_cleansed_NoHo', 'neighbourhood_cleansed_Nolita', 'neighbourhood_cleansed_North Riverdale', 'neighbourhood_cleansed_Norwood', 'neighbourhood_cleansed_Oakwood', 'neighbourhood_cleansed_Olinville', 'neighbourhood_cleansed_Ozone Park', 'neighbourhood_cleansed_Park Slope', 'neighbourhood_cleansed_Parkchester', 'neighbourhood_cleansed_Pelham Bay', 'neighbourhood_cleansed_Pelham Gardens', 'neighbourhood_cleansed_Port Morris', 'neighbourhood_cleansed_Port Richmond', "neighbourhood_cleansed_Prince's Bay", 'neighbourhood_cleansed_Prospect Heights', 'neighbourhood_cleansed_Prospect-Lefferts Gardens', 'neighbourhood_cleansed_Queens Village', 'neighbourhood_cleansed_Randall Manor', 'neighbourhood_cleansed_Red Hook', 'neighbourhood_cleansed_Rego Park', 'neighbourhood_cleansed_Richmond Hill', 'neighbourhood_cleansed_Richmondtown', 'neighbourhood_cleansed_Ridgewood', 'neighbourhood_cleansed_Riverdale', 'neighbourhood_cleansed_Rockaway Beach', 'neighbourhood_cleansed_Roosevelt Island', 'neighbourhood_cleansed_Rosebank', 'neighbourhood_cleansed_Rosedale', 'neighbourhood_cleansed_Rossville', 'neighbourhood_cleansed_Schuylerville', 'neighbourhood_cleansed_Sea Gate', 'neighbourhood_cleansed_Sheepshead Bay', 'neighbourhood_cleansed_Shore Acres', 'neighbourhood_cleansed_Silver Lake', 'neighbourhood_cleansed_SoHo', 'neighbourhood_cleansed_Soundview', 'neighbourhood_cleansed_South Beach', 'neighbourhood_cleansed_South Ozone Park', 'neighbourhood_cleansed_South Slope', 'neighbourhood_cleansed_Springfield Gardens', 'neighbourhood_cleansed_Spuyten Duyvil', 'neighbourhood_cleansed_St. Albans', 'neighbourhood_cleansed_St. George', 'neighbourhood_cleansed_Stapleton', 'neighbourhood_cleansed_Stuyvesant Town', 'neighbourhood_cleansed_Sunnyside', 'neighbourhood_cleansed_Sunset Park', 'neighbourhood_cleansed_Theater District', 'neighbourhood_cleansed_Throgs Neck', 'neighbourhood_cleansed_Todt Hill', 'neighbourhood_cleansed_Tompkinsville', 'neighbourhood_cleansed_Tottenville', 'neighbourhood_cleansed_Tremont', 'neighbourhood_cleansed_Tribeca', 'neighbourhood_cleansed_Two Bridges', 'neighbourhood_cleansed_Unionport', 'neighbourhood_cleansed_University Heights', 'neighbourhood_cleansed_Upper East Side', 'neighbourhood_cleansed_Upper West Side', 'neighbourhood_cleansed_Van Nest', 'neighbourhood_cleansed_Vinegar Hill', 'neighbourhood_cleansed_Wakefield', 'neighbourhood_cleansed_Washington Heights', 'neighbourhood_cleansed_West Brighton', 'neighbourhood_cleansed_West Farms', 'neighbourhood_cleansed_West Village', 'neighbourhood_cleansed_Westchester Square', 'neighbourhood_cleansed_Westerleigh', 'neighbourhood_cleansed_Whitestone', 'neighbourhood_cleansed_Williamsbridge', 'neighbourhood_cleansed_Williamsburg', 'neighbourhood_cleansed_Windsor Terrace', 'neighbourhood_cleansed_Woodhaven', 'neighbourhood_cleansed_Woodlawn', 'neighbourhood_cleansed_Woodrow', 'neighbourhood_cleansed_Woodside', 'property_type_House', 'property_type_Other', 'room_type_Entire home/apt', 'room_type_Hotel room', 'room_type_Shared room', 'bathrooms_text_0 baths', 'bathrooms_text_0 shared baths', 'bathrooms_text_1 bath', 'bathrooms_text_1 private bath', 'bathrooms_text_1 shared bath', 'bathrooms_text_1.5 baths', 'bathrooms_text_1.5 shared baths', 'bathrooms_text_2 baths', 'bathrooms_text_2 shared baths', 'bathrooms_text_2.5 baths', 'bathrooms_text_2.5 shared baths', 'bathrooms_text_3 baths', 'bathrooms_text_3 shared baths', 'bathrooms_text_3.5 baths', 'bathrooms_text_3.5 shared baths', 'bathrooms_text_4 baths', 'bathrooms_text_4 shared baths', 'bathrooms_text_4.5 baths', 'bathrooms_text_4.5 shared baths', 'bathrooms_text_5 baths', 'bathrooms_text_5.5 baths', 'bathrooms_text_6 baths', 'bathrooms_text_6 shared baths', 'bathrooms_text_6.5 baths', 'bathrooms_text_7 baths', 'bathrooms_text_7.5 baths', 'bathrooms_text_8 baths', 'bathrooms_text_Half-bath', 'bathrooms_text_Private half-bath', 'bathrooms_text_Shared half-bath']
# to_drop.extend(list(transformed_df.columns[transformed_df.columns.str.endswith('nan')]))

# transformed_df.drop(to_drop, axis=1, inplace=True)

# %%
# Final assessment of multi-collinearity
multi_collinearity_heatmap(transformed_df.drop(list(transformed_df.columns[transformed_df.columns.str.startswith('borough')]), axis=1), figsize=(25,25), title="Collinearity Heatmap of Airbnb Pricing Features")
# Out:
# C:\Users\51370\AppData\Local\Temp/ipykernel_33432/3413172762.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
numerical_columns = ['accommodates', 'availability_90', 'bathrooms', 'host_listings_count', 'maximum_nights', 'minimum_nights', 'number_of_reviews', 'price']

# %%
transformed_df[numerical_columns].hist(figsize=(10,11));

# %%
# Log transforming columns
numerical_columns = [i for i in numerical_columns if i not in ['availability_90', 'host_days_active']] # Removing items not to be transformed

for col in numerical_columns:
    transformed_df[col] = transformed_df[col].astype('float64').replace(0.0, 0.01) # Replacing 0s with 0.01
    transformed_df[col] = np.log(transformed_df[col])

# %%
transformed_df[numerical_columns].hist(figsize=(10,11));

# %%
# Separating X and y
X = transformed_df.drop('price', axis=1)
y = transformed_df.price

# Scaling
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=list(X.columns))
# Out:
# C:\Users\51370\anaconda3\envs\bigdata\lib\site-packages\sklearn\utils\extmath.py:986: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\51370\anaconda3\envs\bigdata\lib\site-packages\sklearn\utils\extmath.py:991: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# C:\Users\51370\anaconda3\envs\bigdata\lib\site-packages\sklearn\utils\extmath.py:1021: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction ** 2 / new_sample_count

# %% [markdown]
# ## Neural Network Building

# %%
# Splitting into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
xgb_reg_start = time.time()

xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X_train, y_train)
training_preds_xgb_reg = xgb_reg.predict(X_train)
val_preds_xgb_reg = xgb_reg.predict(X_test)

xgb_reg_end = time.time()

print(f"Time taken to run: {round((xgb_reg_end - xgb_reg_start)/60,1)} minutes")
print("\nTraining MSE:", round(mean_squared_error(y_train, training_preds_xgb_reg),4))
print("Validation MSE:", round(mean_squared_error(y_test, val_preds_xgb_reg),4))
print("\nTraining r2:", round(r2_score(y_train, training_preds_xgb_reg),4))
print("Validation r2:", round(r2_score(y_test, val_preds_xgb_reg),4))
# Out:
# Time taken to run: 0.0 minutes
#
# Training MSE: 0.1313
# Validation MSE: 0.1814
#
# Training r2: 0.7505
# Validation r2: 0.6595

# %%
ft_weights_xgb_reg = pd.DataFrame(xgb_reg.feature_importances_, columns=['weight'], index=X_train.columns)
ft_weights_xgb_reg.sort_values('weight', inplace=True)
ft_weights_xgb_reg
# Out:
#                                          weight
# long_term_stays                        0.000000
# review_scores_communication_0-8/10     0.000000
# review_scores_rating_0-79/100          0.000000
# property_type_Other                    0.000000
# review_scores_location_0-8/10          0.000000
# bathrooms                              0.000000
# bathrooms_text_8 baths                 0.000000
# bathrooms_text_7.5 baths               0.000000
# bathrooms_text_7 baths                 0.000000
# bathrooms_text_6.5 baths               0.000000
# bathrooms_text_3.5 shared baths        0.000000
# bathrooms_text_4.5 shared baths        0.000000
# bathrooms_text_6 baths                 0.000152
# bathrooms_text_6 shared baths          0.000316
# bathrooms_text_4 shared baths          0.000345
# property_type_House                    0.000419
# bathrooms_text_5.5 baths               0.000618
# bathrooms_text_4.5 baths               0.000676
# bathrooms_text_Private half-bath       0.000694
# bathrooms_text_4 baths                 0.000973
# bathrooms_text_5 baths                 0.001077
# bathrooms_text_Shared half-bath        0.001186
# number_of_reviews_l30d                 0.001372
# review_scores_value_0-8/10             0.001438
# host_is_superhost                      0.001488
# host_greeting                          0.001500
# bathrooms_text_Half-bath               0.001576
# bathrooms_text_0 shared baths          0.001601
# review_scores_cleanliness_0-8/10       0.001612
# host_has_profile_pic                   0.001678
# beds                                   0.001884
# number_of_reviews                      0.001979
# bathrooms_text_0 baths                 0.001983
# bed_linen                              0.002099
# bathrooms_text_2.5 baths               0.002108
# room_type_Private room                 0.002121
# bathrooms_text_3 shared baths          0.002175
# bathrooms_text_2.5 shared baths        0.002370
# bathrooms_text_3 baths                 0.002391
# coffee_machine                         0.002499
# maximum_nights                         0.002588
# host_identity_verified                 0.002651
# reviews_per_month                      0.002711
# cooking_basics                         0.002754
# number_of_reviews_ltm                  0.002809
# review_scores_accuracy_0-8/10          0.003451
# host_response_time_within a day        0.003753
# bathrooms_text_2 shared baths          0.003759
# has_availability                       0.003769
# private_entrance                       0.003899
# host_response_time_a few days or more  0.003903
# host_response_time_within an hour      0.004151
# instant_bookable                       0.004194
# air_conditioning                       0.004667
# internet                               0.004821
# parking                                0.005154
# bathrooms_text_1.5 shared baths        0.005404
# bathrooms_text_3.5 baths               0.005533
# bathrooms_text_2 baths                 0.005699
# room_type_Shared room                  0.005773
# bathrooms_text_1.5 baths               0.005920
# minimum_nights                         0.005932
# availability_90                        0.005939
# host_response_time_within a few hours  0.006283
# review_scores_checkin_0-8/10           0.006482
# bedrooms                               0.006613
# host_listings_count                    0.007239
# white_goods                            0.008341
# tv                                     0.009520
# bathrooms_text_1 shared bath           0.011706
# elevator                               0.012872
# room_type_Hotel room                   0.017698
# accommodates                           0.019752
# gym                                    0.026676
# bathrooms_text_1 private bath          0.074135
# bathrooms_text_1 bath                  0.117212
# room_type_Entire home/apt              0.535906

# %%
# Plotting feature importances
plt.figure(figsize=(8,20))
plt.barh(ft_weights_xgb_reg.index, ft_weights_xgb_reg.weight, align='center') 
plt.title("Feature importances in the XGBoost model", fontsize=14)
plt.xlabel("Feature importance")
plt.margins(y=0.01)
plt.show()

# %%
# Median price for different host listing counts
plt.figure()
df.groupby('host_listings_count').price.median().plot(figsize=(20,4), kind='bar')
plt.title('Median price of listings hosted by hosts who are responsible for other properties')
plt.xlabel('Number of properties managed by hosts')
plt.ylabel('Median price (£)');

# %%
# Building the model
nn2 = models.Sequential()
nn2.add(layers.Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
nn2.add(layers.Dense(256, activation='relu'))
nn2.add(layers.Dense(256, activation='relu'))
nn2.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn2.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Model summary
print(nn2.summary())

# Visualising the neural network
SVG(model_to_dot(nn2, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               9984
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 109,057
# Trainable params: 109,057
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn2_start = time.time()

nn2_history = nn2.fit(X_train,
                  y_train,
                  epochs=100,
                  batch_size=256,
                  validation_split = 0.1)

nn2_end = time.time()

print(f"Time taken to run: {round((nn2_end - nn2_start)/60,1)} minutes")
# Out:
# Epoch 1/100
# 107/107 [==============================] - 0s 4ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 2/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 3/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 4/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 5/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 6/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 7/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 8/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 9/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 10/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 11/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 12/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 13/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 14/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 15/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 16/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 17/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 18/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 19/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 20/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 21/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 22/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 23/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 24/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 25/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 26/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 27/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 28/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 29/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 30/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 31/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 32/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 33/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 34/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 35/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 36/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 37/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 38/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 39/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 40/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 41/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 42/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 43/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 44/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 45/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 46/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 47/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 48/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 49/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 50/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 51/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 52/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 53/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 54/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 55/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 56/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 57/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 58/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 59/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 60/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 61/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 62/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 63/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 64/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 65/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 66/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 67/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 68/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 69/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 70/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 71/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 72/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 73/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 74/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 75/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 76/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 77/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 78/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 79/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 80/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 81/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 82/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 83/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 84/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 85/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 86/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 87/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 88/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 89/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 90/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 91/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 92/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 93/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 94/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 95/100
# 107/107 [==============================] - 0s 2ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 96/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 97/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 98/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 99/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Epoch 100/100
# 107/107 [==============================] - 0s 3ms/step - loss: nan - mean_squared_error: nan - val_loss: nan - val_mean_squared_error: nan
# Time taken to run: 0.5 minutes

# %%
def nn_model_evaluation(model, skip_epochs=0, X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test):
    """
    For a given neural network model that has already been fit, prints for the train and tests sets the MSE and r squared
    values, a line graph of the loss in each epoch, and a scatterplot of predicted vs. actual values with a line
    representing where predicted = actual values. Optionally, a value for skip_epoch can be provided, which skips that
    number of epochs in the line graph of losses (useful in cases where the loss in the first epoch is orders of magnitude
    larger than subsequent epochs). Training and test sets can also optionally be specified.
    """

    # MSE and r squared values
    y_test_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train)
    # print("Training MSE:", round(mean_squared_error(y_train, y_train_pred),4))
    # print("Validation MSE:", round(mean_squared_error(y_test, y_test_pred),4))
    # print("\nTraining r2:", round(r2_score(y_train, y_train_pred),4))
    # print("Validation r2:", round(r2_score(y_test, y_test_pred),4))
    
    # Line graph of losses
    model_results = model.history.history
    plt.plot(list(range((skip_epochs+1),len(model_results['loss'])+1)), model_results['loss'][skip_epochs:], label='Train')
    plt.plot(list(range((skip_epochs+1),len(model_results['val_loss'])+1)), model_results['val_loss'][skip_epochs:], label='Test', color='green')
    plt.legend()
    plt.title('Training and test loss at each epoch', fontsize=14)
    plt.show()
    
    # Scatterplot of predicted vs. actual values
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    fig.suptitle('Predicted vs. actual values', fontsize=14, y=1)
    plt.subplots_adjust(top=0.93, wspace=0)
    
    ax1.scatter(y_test, y_test_pred, s=2, alpha=0.7)
    ax1.plot(list(range(2,8)), list(range(2,8)), color='black', linestyle='--')
    ax1.set_title('Test set')
    ax1.set_xlabel('Actual values')
    ax1.set_ylabel('Predicted values')
    
    ax2.scatter(y_train, y_train_pred, s=2, alpha=0.7)
    ax2.plot(list(range(2,8)), list(range(2,8)), color='black', linestyle='--')
    ax2.set_title('Train set')
    ax2.set_xlabel('Actual values')
    ax2.set_ylabel('')
    ax2.set_yticklabels(labels='')
    
    plt.show()

# %%
nn_model_evaluation(nn2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33432/427214875.py in <module>
# ----> 1 nn_model_evaluation(nn2)
#
# ~\AppData\Local\Temp/ipykernel_33432/2809021693.py in nn_model_evaluation(model, skip_epochs, X_train, X_test, y_train, y_test)
#      18     # Line graph of losses
#      19     model_results = model.history.history
# ---> 20     plt.plot(list(range((skip_epochs+1),len(model_results['loss'])+1)), model_results['loss'][skip_epochs:], label='Train')
#      21     plt.plot(list(range((skip_epochs+1),len(model_results['val_loss'])+1)), model_results['val_loss'][skip_epochs:], label='Test', color='green')
#      22     plt.legend()
#
# KeyError: 'loss'

# %%
model = nn2
y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)
# print("Training MSE:", round(mean_squared_error(y_train, y_train_pred),4))
# print("Validation MSE:", round(mean_squared_error(y_test, y_test_pred),4))
# print("\nTraining r2:", round(r2_score(y_train, y_train_pred),4))
# print("Validation r2:", round(r2_score(y_test, y_test_pred),4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yj/_63z7pg17ln8p39zw_yh_lsh0000gn/T/ipykernel_27398/1987104841.py in <module>
#       2 y_test_pred = model.predict(X_test)
#       3 y_train_pred = model.predict(X_train)
# ----> 4 print("Training MSE:", round(mean_squared_error(y_train, y_train_pred),4))
#       5 # print("Validation MSE:", round(mean_squared_error(y_test, y_test_pred),4))
#       6 # print("\nTraining r2:", round(r2_score(y_train, y_train_pred),4))
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     333     0.825...
#     334     """
# --> 335     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     336         y_true, y_pred, multioutput)
#     337     check_consistent_length(y_true, y_pred, sample_weight)
#
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      88     check_consistent_length(y_true, y_pred)
#      89     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# ---> 90     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      91
#      92     if y_true.ndim == 1:
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718
#     719         if force_all_finite:
# --> 720             _assert_all_finite(array,
#     721                                allow_nan=force_all_finite == 'allow-nan')
#     722
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
np.isnan(X)
# Out:
#        host_is_superhost  host_listings_count  host_has_profile_pic  \
# 0                  False                False                 False
# 1                  False                False                 False
# 2                  False                False                 False
# 3                  False                False                 False
# 4                  False                False                 False
# ...                  ...                  ...                   ...
# 37708              False                False                 False
# 37709              False                False                 False
# 37710              False                False                 False
# 37711              False                False                 False
# 37712              False                False                 False
#
#        host_identity_verified  accommodates  bathrooms  bedrooms   beds  \
# 0                       False         False       True     False  False
# 1                       False         False       True     False  False
# 2                       False         False       True     False  False
# 3                       False         False       True     False  False
# 4                       False         False       True     False  False
# ...                       ...           ...        ...       ...    ...
# 37708                   False         False       True     False  False
# 37709                   False         False       True     False  False
# 37710                   False         False       True     False  False
# 37711                   False         False       True     False  False
# 37712                   False         False       True     False  False
#
#        minimum_nights  maximum_nights  has_availability  availability_90  \
# 0               False           False             False            False
# 1               False           False             False            False
# 2               False           False             False            False
# 3               False           False             False            False
# 4               False           False             False            False
# ...               ...             ...               ...              ...
# 37708           False           False             False            False
# 37709           False           False             False            False
# 37710           False           False             False            False
# 37711           False           False             False            False
# 37712           False           False             False            False
#
#        number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                  False                  False                   False
# 1                  False                  False                   False
# 2                  False                  False                   False
# 3                  False                  False                   False
# 4                  False                  False                   False
# ...                  ...                    ...                     ...
# 37708              False                  False                   False
# 37709              False                  False                   False
# 37710              False                  False                   False
# 37711              False                  False                   False
# 37712              False                  False                   False
#
#        instant_bookable  reviews_per_month  check_in_24h  air_conditioning  \
# 0                 False              False          True             False
# 1                 False              False          True             False
# 2                 False              False          True             False
# 3                 False              False          True             False
# 4                 False              False          True             False
# ...                 ...                ...           ...               ...
# 37708             False               True          True              True
# 37709             False               True          True              True
# 37710             False               True          True             False
# 37711             False               True          True              True
# 37712             False               True          True              True
#
#        bed_linen     tv  coffee_machine  cooking_basics  white_goods  \
# 0          False  False           False           False        False
# 1          False  False           False           False        False
# 2          False  False           False           False        False
# 3          False  False           False           False        False
# 4          False  False           False           False        False
# ...          ...    ...             ...             ...          ...
# 37708      False  False           False           False        False
# 37709      False  False           False           False        False
# 37710      False  False           False           False        False
# 37711      False  False           False           False        False
# 37712      False  False           False           False        False
#
#        elevator    gym  parking  host_greeting  internet  long_term_stays  \
# 0         False  False    False          False     False            False
# 1         False  False    False          False     False            False
# 2         False  False    False          False     False            False
# 3         False  False    False          False     False            False
# 4         False  False    False          False     False            False
# ...         ...    ...      ...            ...       ...              ...
# 37708     False  False    False          False     False            False
# 37709     False  False    False          False     False            False
# 37710     False  False    False          False     False            False
# 37711     False  False    False          False     False            False
# 37712     False  False    False          False     False            False
#
#        private_entrance  host_response_time_a few days or more  \
# 0                 False                                  False
# 1                 False                                  False
# 2                 False                                  False
# 3                 False                                  False
# 4                 False                                  False
# ...                 ...                                    ...
# 37708             False                                  False
# 37709             False                                  False
# 37710             False                                  False
# 37711             False                                  False
# 37712             False                                  False
#
#        host_response_time_within a day  host_response_time_within a few hours  \
# 0                                False                                  False
# 1                                False                                  False
# 2                                False                                  False
# 3                                False                                  False
# 4                                False                                  False
# ...                                ...                                    ...
# 37708                            False                                  False
# 37709                            False                                  False
# 37710                            False                                  False
# 37711                            False                                  False
# 37712                            False                                  False
#
#        host_response_time_within an hour  host_response_rate_0%  \
# 0                                  False                  False
# 1                                  False                  False
# 2                                  False                  False
# 3                                  False                  False
# 4                                  False                  False
# ...                                  ...                    ...
# 37708                              False                  False
# 37709                              False                  False
# 37710                              False                  False
# 37711                              False                  False
# 37712                              False                  False
#
#        host_response_rate_10%  host_response_rate_100%  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ...                       ...                      ...
# 37708                   False                    False
# 37709                   False                    False
# 37710                   False                    False
# 37711                   False                    False
# 37712                   False                    False
#
#        room_type_Private room  review_scores_rating_0-79/100  \
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
# ...                       ...                            ...
# 37708                   False                          False
# 37709                   False                          False
# 37710                   False                          False
# 37711                   False                          False
# 37712                   False                          False
#
#        review_scores_accuracy_0-8/10  review_scores_cleanliness_0-8/10  \
# 0                              False                             False
# 1                              False                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
# ...                              ...                               ...
# 37708                          False                             False
# 37709                          False                             False
# 37710                          False                             False
# 37711                          False                             False
# 37712                          False                             False
#
#        review_scores_checkin_0-8/10  review_scores_communication_0-8/10  \
# 0                             False                               False
# 1                             False                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
# ...                             ...                                 ...
# 37708                         False                               False
# 37709                         False                               False
# 37710                         False                               False
# 37711                         False                               False
# 37712                         False                               False
#
#        review_scores_location_0-8/10  review_scores_value_0-8/10  \
# 0                              False                       False
# 1                              False                       False
# 2                              False                       False
# 3                              False                       False
# 4                              False                       False
# ...                              ...                         ...
# 37708                          False                       False
# 37709                          False                       False
# 37710                          False                       False
# 37711                          False                       False
# 37712                          False                       False
#
#        time_since_first_review_0-6 months  time_since_first_review_1-2 years  \
# 0                                   False                              False
# 1                                   False                              False
# 2                                   False                              False
# 3                                   False                              False
# 4                                   False                              False
# ...                                   ...                                ...
# 37708                               False                              False
# 37709                               False                              False
# 37710                               False                              False
# 37711                               False                              False
# 37712                               False                              False
#
#        time_since_first_review_2-3 years  time_since_first_review_4+ years  \
# 0                                  False                             False
# 1                                  False                             False
# 2                                  False                             False
# 3                                  False                             False
# 4                                  False                             False
# ...                                  ...                               ...
# 37708                              False                             False
# 37709                              False                             False
# 37710                              False                             False
# 37711                              False                             False
# 37712                              False                             False
#
#        time_since_first_review_6-12 months  time_since_last_review_0-2 weeks  \
# 0                                    False                             False
# 1                                    False                             False
# 2                                    False                             False
# 3                                    False                             False
# 4                                    False                             False
# ...                                    ...                               ...
# 37708                                False                             False
# 37709                                False                             False
# 37710                                False                             False
# 37711                                False                             False
# 37712                                False                             False
#
#        time_since_last_review_1+ year  time_since_last_review_2-6 months  \
# 0                               False                              False
# 1                               False                              False
# 2                               False                              False
# 3                               False                              False
# 4                               False                              False
# ...                               ...                                ...
# 37708                           False                              False
# 37709                           False                              False
# 37710                           False                              False
# 37711                           False                              False
# 37712                           False                              False
#
#        time_since_last_review_2-8 weeks  time_since_last_review_6-12 months
# 0                                 False                               False
# 1                                 False                               False
# 2                                 False                               False
# 3                                 False                               False
# 4                                 False                               False
# ...                                 ...                                 ...
# 37708                             False                               False
# 37709                             False                               False
# 37710                             False                               False
# 37711                             False                               False
# 37712                             False                               False
#
# [37713 rows x 56 columns]

# %%
np.isnan(y_train.values.any())
# Out:
# False

# %%
np.nan_to_num(X)
# Out:
# array([[-0.49238321,  0.73454995,  0.08089702, ..., -0.15120885,
#         -0.07002053, -0.17268166],
#        [-0.49238321, -0.10733174,  0.08089702, ..., -0.15120885,
#         -0.07002053, -0.17268166],
#        [-0.49238321, -0.10733174,  0.08089702, ..., -0.15120885,
#         -0.07002053, -0.17268166],
#        ...,
#        [-0.49238321,  0.86347897,  0.08089702, ..., -0.15120885,
#         -0.07002053, -0.17268166],
#        [-0.49238321,  2.07448521,  0.08089702, ..., -0.15120885,
#         -0.07002053, -0.17268166],
#        [-0.49238321,  2.07448521,  0.08089702, ..., -0.15120885,
#         -0.07002053, -0.17268166]])

# %%
X_train.fillna(X_train.mean())
X_test.fillna(X_test.mean())
y_test.fillna(y_test.mean())
y_train.fillna(y_train.mean())
# Out:
# id
# 41396507    4.007333
# 45924235    4.744932
# 9475136     4.499810
# 30396953    4.976734
# 568661      4.442651
#               ...
# 10043483    4.584967
# 22484057    3.555348
# 27677869    4.174387
# 45191374    4.465908
# 23188871    4.248495
# Name: price, Length: 30170, dtype: float64
